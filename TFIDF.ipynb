# %%
# A scientific computing package
import numpy as np

# Data visualization & analysis package
import pandas as pd

# Data preprocessing
# Deep-learning package but we only use this package for
# some preprocessing tasks
import tensorflow as tf
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.stem import PorterStemmer

# Sklearn provides some machine-learning function
# TFIDF for convert documents to vector representation
# Euclidean Distance tell us the distance between vectors
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import euclidean_distances

# Utilities
from langdetect import detect
from googletrans import Translator

# %%
data = pd.read_csv("./data/books.csv",index_col=0)

# %%
data.sample(20)
# Out:
#       Id                                              Title  \
# 452  492  Collins English For Life - Writing (A2 - Pre I...
# 161  623  The Digital Quality Handbook: A Guide for Achi...
# 144  327                                   The Last Lecture
# 14   367  Global Outsourcing: Executing an Onshore, Near...
# 465  525   Oxford Learner's Pocket Phrasal Verbs and Idioms
# 395  141         Cẩm Nang Kinh Doanh - Giao Tiếp Thương Mại
# 33   217                Payment Technologies for E-Commerce
# 408  165        Cẩm Nang Kinh Doanh - Kỹ Năng Thương Lượng
# 46   422  Carrots and Sticks Don't Work: Build a Culture...
# 187  387         How to Reduce the Cost of Software Testing
# 430  315  Getting Started with PegaRULES Process Command...
# 295  185  Object-Oriented JavaScript: Create scalable, r...
# 409  166            Cẩm Nang Kinh Doanh - Quản Lý Thời Gian
# 317  248                         Strengths-Based Leadership
# 68   191                    The IT Manager's Survival Guide
# 389  132  Cẩm Nang Quản Lý Hiệu Quả - Phát Triển Nghề Ng...
# 347   87                         Tôi Tài Giỏi Bạn Cũng Thế!
# 181   64    Patterns of Enterprise Application Architecture
# 308  473                                    Docker Cookbook
# 438  441                                   KMS's 5th Kindle
#
#                                            description
# 452                                                NaN
# 161  As mobile and web technologies continue to exp...
# 144  A lot of professors give talks titled "The Las...
# 14   Global outsourcing is defined as the seamless ...
# 465  •Learn phrases and expressions for everyday si...
# 395  Bộ sách nổi tiếng Cẩm nang kinh doanh Harvard ...
# 33   Electronic payment is the economic backbone of...
# 408  Bộ sách nổi tiếng “Cẩm nang Kinh doanh Harvard...
# 46   Advance praise for Carrots and Sticks Don't Wo...
# 187  Plenty of software testing books tell you how ...
# 430                                                NaN
# 295  Create scalable and reusable high-quality Java...
# 409  Bộ sách nổi tiếng “Cẩm nang Kinh doanh Harvard...
# 317  For decades, Gallup scientists have researched...
# 68   Accessible, refreshingly candid, but above all...
# 389  Khả năng duy trì một triển vọng sự nghiệp năng...
# 347  Every student can achieve and excel if given t...
# 181  The practice of enterprise application develop...
# 308  Whether you’re deploying applications on premi...
# 438                                                NaN

# %% [markdown]
# ## Corpus Cleaning
#
# ### Remove books that have no description
#
# Because we depend on the description of books to measure the similarity between them, a book without a description cannot be used

# %%
no_des = data[data['description'].isnull()]
print(f"Number of books without a description {len(no_des)}")
no_des.head(10)
# Out:
# Number of books without a description 54
#       Id                                              Title description
# 396  151          Cẩm Nang Kinh Doanh - Quản Lý Khủng Hoảng         NaN
# 412  169                                      Đắc Nhân Tâm          NaN
# 413  170                Sắp Xếp Quyền Ưu Tiên Cho Công Việc         NaN
# 418  196       Toàn Cảnh Công Nghiệp Phần Mềm Việt Nam 2010         NaN
# 419  213            The Big Book of Humorous Training Games         NaN
# 420  222                        Phát triển kỹ năng Lãnh Đạo         NaN
# 421  223                            QBQ - Tư duy thông minh         NaN
# 422  274                  Collective Intelligence in Action         NaN
# 423  290  Pocket Glossary of Health Information Manageme...         NaN
# 424  308                  HL7  - CDA: an XML example UH-201         NaN

# %%
# Drop books that have no description
data = data[~data['description'].isnull()].reset_index(drop=True)

# %% [markdown]
# ### Translate vietnamese description to english
# It's not a good idea to work with 2 languages simultaneously in a NLP problem, so we will do our best to convert all vietnamese description to english with Google Translate Api, it's not very accurate but it will do for now.

# %%
not_english = []
for idx,row in data.iterrows():
    des = row['description']
    lang = detect(des)
    if (lang!='en'):
        not_english.append(row['Id'])
not_english = data[data['Id'].isin(not_english)]

# %%
print(f"Number of books with a description that not in 'English': {len(not_english)}")
not_english.head(10)
# Out:
# Number of books with a description that not in 'English': 62
#       Id                                              Title  \
# 360  101  Bí Quyết Thành Công - Để Hiệu Quả Trong Công Việc
# 361  102  Sức Mạnh Của Sự Khích Lệ (Bí Quyết Thành Công ...
# 362  103           Bí Quyết Tuyển Dụng Và Đãi Ngộ Người Tài
# 363  104  Bí Quyết Thành Công - Câu Chuyện Nhà Quản Lý C...
# 364  105    Cẩm Nang Quản Lý Hiệu Quả - Quản Lý Sự Thay Đổi
# 365  106   Cẩm Nang Quản Lý Hiệu Quả - Tư Duy Chiến Lược
# 366  107       Cẩm Nang Quản Lý Hiệu Quả - Quản Lý Toàn Cầu
# 367  108      Cẩm Nang Quản Lý Hiệu Quả - Quản Lý Ngân Sách
# 368  109      Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng Phỏng Vấn
# 369  110     Cẩm Nang Quản Lý Hiệu Quả - Hành Động Hiệu Quả
#
#                                            description
# 360  Kỹ năng xác định những mục tiêu ưu tiên, khắc ...
# 361  Thông qua câu chuyện thú vị có thật về việc hu...
# 362  "Bí Quyết Tuyển Dụng Và Đãi Ngộ Người Tài" là ...
# 363  Bạn đang cầm trên tay quyển sách đã được dịch ...
# 364  Cuốn sách Quản Lý Sự Thay Đổi này sẽ hướng dẫn...
# 365  Có khả năng hoạch định dài hạn trong khi vẫn p...
# 366  Những kỹ năng thực tế hướng dẫn bạn cách thích...
# 367  Cách sử dụng và quản lý ngân sách như một công...
# 368  Việc phỏng vấn tuyển dụng nhân viên, dù là thư...
# 369  "Người bình thường chờ đợi và thực hiện tuần t...

# %%
trans = Translator()

# %%
for idx,row in not_english.iterrows():
    translations = trans.translate(row['description']).text
    not_english.at[idx,'description'] = translations
    data.at[idx,'description'] = translations

# %%
not_english.sample(10)
# Out:
#       Id                                              Title  \
# 420  534          Academic Essay Writing - Tự Học Viết Luận
# 413  175                           7 Thói Quen Để Thành Đạt
# 368  109      Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng Phỏng Vấn
# 409  167  Hạt Giống Tâm Hồn - Thay Thái Độ Đổi Cuộc Đời ...
# 423  555                              Sẵn sàng cho mọi việc
# 402  159     Cẩm Nang Kinh Doanh - Quản Lý Dự Án Lớn Và Nhỏ
# 411  172  Trò Chơi Tiên Đoán - Dự Báo Và Định Trước Tươn...
# 367  108      Cẩm Nang Quản Lý Hiệu Quả - Quản Lý Ngân Sách
# 400  157  Cẩm Nang Kinh Doanh - Xây Dựng Nhóm Làm Việc H...
# 403  160  Cẩm Nang Kinh Doanh - Quản Lý Tính Sáng Tạo & ...
#
#                                            description
# 420  ACADEMIC WRITING Essay Book (SELF STUDY essay)...
# 413  Increasingly complex life, stress and harsh as...
# 368  The recruitment interview, whether regularly o...
# 409  Attitude is Everything by Keith D. Harrell for...
# 423  You do not need to work harder. Even you may n...
# 402  Ministry of Harvard Business Plan - Harvard Bu...
# 411  Bruce Bueno de Mesquita is a master of game th...
# 367  Usage and budget management as a business tool...
# 400  Ministry of Harvard Business Plan - Harvard Bu...
# 403  The book provides the basic guidelines for a m...

# %% [markdown]
# ### Turn table format to array

# %%
corpus = data['description'].values

# %%
corpus
# Out:
# array(['Companies of all sizes are finding an urgent new priority--keeping employees. This book takes the reader through the critical ideas of employee retention using what is called the Three Rs of Employee Retention--Respect, Recognition, and Rewards--as the basis for any program designed to keep people around.',
#        "Written by a software developer for software developers, this book is a unique collection of the latest software development methods. The author includes OOD, UML, Design Patterns, Agile and XP methods with a detailed description of a complete software design for reusable programs in C++ and Java. Using a practical, problem-solving approach, it shows how to develop an object-oriented application—from the early stages of analysis, through the low-level design and into the implementation. Walks readers through the designer's thoughts — showing the errors, blind alleys, and creative insights that occur throughout the software design process. The book covers: Statics and Dynamics; Principles of Class Design; Complexity Management; Principles of Package Design; Analysis and Design; Patterns and Paradigm Crossings. Explains the principles of OOD, one by one, and then demonstrates them with numerous examples, completely worked-through designs, and case studies. Covers traps, pitfalls, and work arounds in the application of C++ and OOD and then shows how Agile methods can be used. Discusses the methods for designing and developing big software in detail. Features a three-chapter, in-depth, single case study of a building security system. For Software Engineers, Programmers, and Analysts who want to understand how to design object oriented software with state of the art methods.   ",
#        '"Texts must be interesting enough for students to want to read them in their own language. Otherwise, how can we expect students to want to read them in English?"This is the authors\' golden rule when they choose texts and topics for every level of American English File. It ensures you get material that learners will enjoy reading and will want to talk about. Texts such as \'Could you live without money?\' really help to generate opinion and discussion. They create a desire to communicate.Having created the desire, American English File then helps you to develop learners\' communication skills. One way it does this is with a strong focus on pronunciation. Research shows that poor pronunciation is a major contributor to breakdowns in communication (Jennifer Jenkins: The Phonology of English as an International Language).American English File integrates pronunciation into every lesson - the \'little and often\' approach. But that\'s not all.The unique English File Sounds Chart puts a picture to each sound in the phonetic alphabet, so learners find it easier to remember the sounds and, ultimately, improve their pronunciation.',
#        'Table of content: section 1: 1 career 2 getting started with a "bang!": don\'t do what everyone else does 3 thinking about the future: what are your goals? 4 people skills: you need them more than you think 5 hacking the interview 6 employment options: enumerate your choices 7 what kind of software developer are you? 8 not all companies are equal 9 climbing the corporate ladder 10 being a professional 11 freedom: how to quit your job 12 freelancing: going out on your own 13 creating your first product 14 do you want to start a startup? 15 working remotely survival strategies 16 fake it till you make it 17 resumes are boring - let\'s fix that 18 don\'t get religious about technology section 2 marketing yourself: 19 marketing basics for code monkeys 20 building a brand that gets you noticed 21 creating a wildly successful blog 22 your primary goal: add value to others 23 using social networks 24 speaking, presenting and training: speak geek 25 writing books and articles that attract a following 26 don\'t be afraid to look like an idiot section 3 learning: 27 learning how to learn: how to teach yourself 28 my 10-step process 29 steps 1-6: do these once 30 steps 7-10: repeat these 31 looking for mentors: finding your yoda 32 taking on an apprentice: being yoda 33 teaching: learn you want? teach you must.',
#        'Nassim Nicholas Taleb, the bestselling author of The Black Swan and one of the foremost thinkers of our time, reveals how to thrive in an uncertain world. \xa0 Just as human bones get stronger when subjected to stress and tension, and rumors or riots intensify when someone tries to repress them, many things in life benefit from stress, disorder, volatility, and turmoil. What Taleb has identified and calls “antifragile” is that category of things that not only gain from chaos but need it in order to survive and flourish.\xa0  \xa0 In The Black Swan, Taleb showed us that highly improbable and unpredictable events underlie almost everything about our world. In Antifragile, Taleb stands uncertainty on its head, making it desirable, even necessary, and proposes that things be built in an antifragile manner. The antifragile is beyond the resilient or robust. The resilient resists shocks and stays the same; the antifragile gets better and better.  \xa0 Furthermore, the antifragile is immune to prediction errors and protected from adverse events. Why is the city-state better than the nation-state, why is debt bad for you, and why is what we call “efficient” not efficient at all? Why do government responses and social policies protect the strong and hurt the weak? Why should you write your resignation letter before even starting on the job? How did the sinking of the Titanic save lives? The book spans innovation by trial and error, life decisions, politics, urban planning, war, personal finance, economic systems, and medicine. And throughout, in addition to the street wisdom of Fat Tony of Brooklyn, the voices and recipes of ancient wisdom, from Roman, Greek, Semitic, and medieval sources, are loud and clear. \xa0 Antifragile is a blueprint for living in a Black Swan world. \xa0 Erudite, witty, and iconoclastic, Taleb’s message is revolutionary: The antifragile, and only the antifragile, will make it.Praise for Antifragile \xa0“Ambitious and thought-provoking . . . highly entertaining.”—The Economist \xa0 “A bold book explaining how and why we should embrace uncertainty, randomness, and error . . . It may just change our lives.”—Newsweek \xa0 “Revelatory . . . [Taleb] pulls the reader along with the logic of a Socrates.”—Chicago Tribune \xa0 “Startling . . . richly crammed with insights, stories, fine phrases and intriguing asides . . . I will have to read it again. And again.”—Matt Ridley, The Wall Street Journal \xa0 “Trenchant and persuasive . . . Taleb’s insatiable polymathic curiosity knows no bounds. . . . You finish the book feeling braver and uplifted.”—New Statesman \xa0 “Antifragility isn’t just sound economic and political doctrine. It’s also the key to a good life.”—Fortune \xa0 “At once thought-provoking and brilliant.”—Los Angeles TimesFrom the Hardcover edition.',
#        'eXtreme Programming is an ideal many software shops would love to reach, but with the constant pressures to produce software quickly, they cannot actually implement it. The Agile software process allows a company to implement eXtreme Programming quickly and immediately-and to begin producing software incrementally in as little as 30 days! Implementing eXtreme Programming is easier said than done. The process can be time consuming and actually slow down current software projects that are in process. This book shows readers how to use SCRUM, an Agile software development process, to quickly and seamlessly implement XP in their shop-while still producing actual software. Using SCRUM and the Agile process can virtually eliminate all downtime during an XP implementation.  ',
#        "This edition provides a comprehensive approach to investments, from the fundamentals needed for success on the CFP exam to more advanced topics. Readers learn to make solid real investment decisions with applications, such as an updated 'Financial Advisor's Investment Case' at the end of each chapter and the latest Internet assignments.",
#        'Culture, leadership and the ability to change determine organizational performance... But 75% of organizational change programs fail - being too conceptual, organization-wide and command-and-control like.  That\'s why change consultant Marcella Bremer developed this pragmatic approach to organizational culture, change and leadership.  The starting point is the validated Organizational Culture Assessment Instrument based on the Competing Values Framework by professors Kim Cameron and Robert Quinn. Next, Bremer shows how to engage people in OCAI-workshops or Change Circles. In peer groups of 10 coworkers they develop a change plan for their teams that is also personal and focused on specific behaviors. These Change Circles of 10 use the mechanism of "Copy, Coach and Correct" within groups to help organization members to implement the change and develop those behaviors that will make a difference. This book is a pragmatic user’s guide to organizational culture change. Learn the best practices from a change consultant and unleash your organization, too!',
#        "Business Plus is a three-level, integrated-skills, business English course, from A1 (false beginner) to B1 (pre-intermediate) levels. Each level of the Student's Book has 10 units. Designed to be easy and enjoyable to teach, each unit features integrated skills and language practice. Units also include cultural awareness sections that connect learners to their region and beyond. In addition, TOEIC-style practice sections allow students' progress to be measured.",
#        'This textbook adopts a unique approach to helping developers and CS students learn Hadoop MapReduce programming fast. Rather than filled with disjointed, piecemeal code snippets to show Hadoop MapReduce programming features one at a time, it is designed to place your total Hadoop MapReduce programming learning process in a common application context of mining customer spending patterns ensconced in large volumes of credit card transaction record data. Precise, end-to-end procedures are given to help you set up your Hadoop MapReduce development environment quickly on Eclipse with Maven on Mac OS X. Step-by-step procedures are also given on how to set up a four-node Linux cluster at minimum so that you can run your MapReduce programs not only in local mode on your Mac OS X machine but also in fully distributed mode on a real cluster. In fact, all MapReduce programs presented in the book have been tested and verified in local mode and on such a Linux cluster.This textbook mainly focuses on teaching Hadoop MapReduce programming in a scientific, objective, quantitative approach. Rather than heavily relying on subjective, verbose (and sometimes even pompous) textual descriptions with sparse code snippets, this textbook uses Hadoop Java APIs, Hadoop configuration parameters, complete MapReduce programs and their execution logs and outputs to demonstrate how Hadoop MapReduce framework works and how to write MapReduce programs. Specifically, this text covers the following subjects:* Introduction to Hadoop* Setting up a Linux Hadoop Cluster* The Hadoop Distributed FileSystem* MapReduce Job Orchestration and Workflows* Basic MapReduce Programming* Advanced MapReduce Programming* Hadoop Streaming* Hadoop AdministrationNo matter what role you play on your team, this text can help you gain truly applicable Hadoop skills in a most effective and efficient manner. The book can also be used as a supplementary textbook for a distributed computing or Hadoop course offered to upper-division college CS students.',
#        "The highly successful security book returns with a new edition, completely updatedWeb applications are the front door to most organizations, exposing them to attacks that may disclose personal information, execute fraudulent transactions, or compromise ordinary users. This practical book has been completely updated and revised to discuss the latest step-by-step techniques for attacking and defending the range of ever-evolving web applications. You'll explore the various new technologies employed in web applications that have appeared since the first edition and review the new attack techniques that have been developed, particularly in relation to the client side.Reveals how to overcome the new technologies and techniques aimed at defending web applications against attacks that have appeared since the previous editionDiscusses new remoting frameworks, HTML5, cross-domain integration techniques, UI redress, framebusting, HTTP parameter pollution, hybrid file attacks, and moreFeatures a companion web site hosted by the authors that allows readers to try out the attacks described, gives answers to the questions that are posed at the end of each chapter, and provides a summarized methodology and checklist of tasksFocusing on the areas of web application security where things have changed in recent years, this book is the most current resource on the critical topic of discovering, exploiting, and preventing web application security flaws..",
#        "This is a practical guide for software developers, and different than other software architecture books. Here's why: It teaches risk-driven architecting. There is no need for meticulous designs when risks are small, nor any excuse for sloppy designs when risks threaten your success. This book describes a way to do just enough architecture. It avoids the one-size-fits-all process tar pit with advice on how to tune your design effort based on the risks you face. It democratizes architecture. This book seeks to make architecture relevant to all software developers. Developers need to understand how to use constraints as guiderails that ensure desired outcomes, and how seemingly small changes can affect a system's properties. It cultivates declarative knowledge. There is a difference between being able to hit a ball and knowing why you are able to hit it, what psychologists refer to as procedural knowledge versus declarative knowledge. This book will make you more aware of what you have been doing and provide names for the concepts. It emphasizes the engineering. This book focuses on the technical parts of software development and what developers do to ensure the system works not job titles or processes. It shows you how to build models and analyze architectures so that you can make principled design tradeoffs. It describes the techniques software designers use to reason about medium to large sized problems and points out where you can learn specialized techniques in more detail. It provides practical advice. Software design decisions influence the architecture and vice versa. The approach in this book embraces drill-down/pop-up behavior by describing models that have various levels of abstraction, from architecture to data structure design.",
#        'Pro Android 2 shows how to build real-world and fun mobile applications using Google’s latest Android software development kit. This new edition is updated for Android 2, covering everything from the fundamentals of building applications for embedded devices to advanced concepts such as custom 3D components, OpenGL, and touchscreens including gestures. While other Android development guides simply discuss topics, Pro Android 2 offers the combination of expert insight and real sample applications that work.       Discover the design and architecture of the Android SDK through practical examples, and how to build mobile applications using the Android SDK.      Explore and use the Android APIs, including those for media and Wi-Fi.      Learn about Android 2’s integrated local and web search, handwriting gesture UI, Google Translate, and text-to-speech features.   Pro Android 2 dives deep, providing you with all the knowledge and techniques you need to build mobile applications ranging from games to Google apps, including add-ons to Google Docs. You’ll be able to extend and run the new Google Chrome APIs on the G1, the G2, and other next-generation Google phones and Android-enabled devices. What you’ll learn     How to use Android to build Java-based mobile applications for Google phones with a touch screen or keyboard (thanks to Cupcake’s inclusion as of Android 1.5)      How to design and architect using Google’s latest Android SDK      How to use the Android SDK to write mobile applications for embedded devices      How to create 3D graphics with OpenGL and custom components      How to build multimedia and game apps using Android’s Media APIs and OpenGL      How to use Android’s location-based services, networking (Wi-Fi APIs), and security      How to create and allow for more integrated local and web searches      How to build handwriting gesture UIs      How to incorporate Google Translate into your Android applications   Who this book is for           This book is for professional software engineers/programmers looking to move their ideas and applications into the mobile space with Android. It assumes that readers have a passable understanding of Java, including being able to write classes and handle basic inheritance structures. This book also targets hobbyists.            Table of Contents     Introducing the Android Computing Platform      Getting Your Feet Wet      Using Resources, Content Providers, and Intents      Building User Interfaces and Using Controls      Working with Menus and Dialogs      Unveiling 2D Animation      Exploring Security and Location-Based Services      Building and Consuming Services      Using the Media Framework and Telephony APIs      Programming 3D Graphics with OpenGL      Managing and Organizing Preferences      Exploring Live Folders      Home Screen Widgets      Android Search      Exploring Text to Speech and Translate APIs      Touchscreens      Titanium Mobile: A WebKit-Based Approach to Android\xa0Development      Working with Android Market      Outlook and Resources  ',
#        'Five years and more than 100,000 copies after it was first published,  it\'s hard to imagine anyone working in Web design who hasn\'t read Steve  Krug\'s "instant classic" on Web usability, but people are still  discovering it every day.\xa0 In this second edition, Steve adds  three new chapters in the same style as the original: wry and  entertaining, yet loaded with insights and practical advice for novice  and veteran alike.\xa0 Don\'t be surprised if it completely changes  the way you think about Web design. With these three new chapters:   Usability as common courtesy -- Why people really leave Web sites Web Accessibility, CSS, and you -- Making sites usable and accessible Help! My boss wants me to ______. -- Surviving executive design whims   "I thought usability was the enemy of design until I read the first edition of this book.\xa0 Don\'t Make Me Think! showed  me how to put myself in the position of the person who uses my  site.\xa0 After reading it over a couple of hours and putting its  ideas to work for the past five years, I can say it has done more to  improve my abilities as a Web designer than any other book.  In  this second edition, Steve Krug adds essential ammunition for those  whose bosses, clients, stakeholders, and marketing managers insist on  doing the wrong thing.\xa0 If you design, write, program, own, or  manage Web sites, you must read this book."\xa0 -- Jeffrey Zeldman,  author of Designing with Web Standards  ',
#        'Global outsourcing is defined as the seamless integration of onsite, onshore, nearshore, and offshore delivery teams. It is rapidly becoming the execution and delivery strategy of choice for business process and IT projects in corporations today. This book goes beyond the theory to explain the step-by-step methodology managers should follow to execute a global outsourcing strategy. Designed as an implementation manual, Global Outsourcing discusses the detailed tasks involved in the planning, sourcing, and execution phases of every project.',
#        'Alice\'s Adventures in Wonderland (1865) is a novel written by English author Charles Lutwidge Dodgson, better known under the pseudonym Lewis Carroll. It tells the story of a girl named Alice who falls down a rabbit-hole into a fantasy world populated by peculiar and anthropomorphic creatures.In 1865, Dodgson\'s tale was published as Alice\'s Adventures in Wonderland by "Lewis Carroll" with illustrations by John Tenniel. The first print run of 2,000 was destroyed because Tenniel had objections over the print quality. A new edition, released in December of the same year but carrying an 1866 date, was quickly printed. This is a reproduction of that edition.',
#        'In a complex world, products that are easy to use win favor with consumers. This is the first book on the topic of simplicity aimed specifically at interaction designers. It shows how to drill down and simplify user experiences when designing digital tools and applications. It begins by explaining why simplicity is attractive, explores the laws of simplicity, and presents proven strategies for achieving simplicity. Remove, hide, organize and displace become guidelines for designers, who learn simplicity by seeing before and after examples and case studies where the results speak for themselves.',
#        "If HIBERNATE makes Java-based, data-persistence, so incredibly easy to perform, then why do all of the most popular resources make Hibernate technology so darned impossible to learn? Well, learning Hibernate doesn't have to be hard anymore; not with a copy of HIBERNATE MADE EASY by your side!     Cameron McKenzie's, Hibernate Made Easy, finally brings to light the idea that a technology that is fun and easy to use, should also be fun and easy to learn. Building upon simple, straight forward examples that make even the most difficult topics easy to understand, this book explores all of the key concepts that you absolutely must know in order to start effectively leveraging the Hibernate framework. Discarding the old, XML based, -hbm- mapping files, Hibernate Made Easy will show you how to simplify your designs by leveraging both Hibernate and JPA annotations together, making your applications more manageable, maintainable, and most importantly, faster and easier to develop!    From the fundamental, Create, Retrieve, Update & Delete operations, to the mapping of complex inheritance hierarchies, Hibernate Made Easy explains it, using a friendly and conversational style that reads less like a technical book, and more like an informative conversation with a Hibernate expert.     And while the examples in the book are incredibly easy to follow and reproduce (---there are no code errors in this book -- that is guaranteed!---), the concepts this book will help you learn will empower you to solve even the most daunting programming challenges. From managing transactions over an HTTP based request-response cycle, to implementing highly advanced Data Access Objects (DAOs) with Java 5 generics, this book will teach you what you really need to know about Java based persistence with Hibernate.     If you want to learn Hibernate, if you want to learn Hibernate quickly, and you want it explained in a manner that is easy to follow and understand, there really is no other choice. Get a copy of Cameron McKenzie's Hibernate Made Easy today! For more information, check out hiberbook.com",
#        "ASP.NET 4 is the principal standard for creating dynamic web pages on the Windows platform. Pro ASP.NET 4 in C# 2010 raises the bar for high-quality, practical advice on learning and deploying Microsoft's dynamic web solution. This edition is updated with everything you need to master up to version 4\xa0of ASP.NET, including coverage of ASP.NET MVC, ASP.NET AJAX 4, ASP.NET Dynamic Data, and Silverlight 3. Seasoned .NET professionals Matthew MacDonald and Mario Szpuszta explain how you can get the most from these groundbreaking technologies. They cover ASP.NET 4 as a whole, illustrating\xa0both the newer features and the functionality carried over from previous versions of ASP. This book will give you the knowledge you need to code real ASP.NET 4 applications in the best possible style.",
#        'No matter how much experience you have with JavaScript, odds are you don’t fully understand the language. As part of the "You Don’t Know JS" series, this compact guide focuses on new features available in ECMAScript 6 (ES6), the latest version of the standard upon which JavaScript is built.Like other books in this series, You Don’t Know JS: ES6 & Beyond dives into trickier parts of the language that many JavaScript programmers either avoid or know nothing about. Armed with this knowledge, you can achieve true JavaScript mastery.With this book, you will:Learn new ES6 syntax that eases the pain points of common programming idiomsOrganize code with iterators, generators, modules, and classesExpress async flow control with Promises combined with generatorsUse collections to work more efficiently with data in structured waysLeverage new API helpers, including Array, Object, Math, Number, and StringExtend your program’s capabilities through meta programmingPreview features likely coming to JS beyond ES6',
#        'The best-practice guide to managing IT infrastructures-now fully updated! nbsp; IT Systems Management is an up-to-the-minute guide to maintaining stable, responsive IT production environments. Top IT systems management expert Rich Schiesser illuminates both the theoretical and practical aspects of systems management, using methods and examples drawn from decades of experience leading and consulting with the world\'s most complex enterprise IT organizations. nbsp; This thoroughly updated edition covers every systems management disciplinenbsp; and all elements of success: people, process, and technology. Schiesser shows how to apply best-practice system management throughout all IT infrastructure environments, from mainframe data centers to web-enabled systems, client/server and mid-range platforms to wireless and VoIP networks.nbsp; nbsp; Schiesser systematically addresses today\'s most crucial issues, as well as emerging trends that will transform IT systems management. You\'ll find an entirely new chapter on using IT Infrastructure Library (ITIL) effectively, plus new coverage ranging from managing outsourced functions to efficiently delivering "ultra-speed" Internet connections. This edition includes more real-life examples throughout, and new interactive problems designed to give IT professionals even deeper insight. Coverage includes: nbsp; *nbsp; Implementing bullet-proof processes in areas ranging from change management to production acceptance, capacity planning to storage *nbsp; Optimizing the "people" components of IT service delivery, from customer service to executive support *nbsp; Using technology to manage systems more efficiently and effectively *nbsp; Systematically managing performance, availability, and business continuity *nbsp; Reducing the cost and complexity of IT facilities management *nbsp; Taking a more strategic approach to security nbsp; nbsp; Rich Schiesser founded and owns RWS Enterprises, Inc., a consultancy that specializes in designing and implementing world-class IT infrastructures. His client list has included The Weather Channel, Amazon.com, and DIRECTV. He has led major IT infrastructure organizations at Hughes Aircraft, the City of Los Angeles, and Twentieth Century Fox. For nearly ten years, he managed the primary data center at Northrop Grumman, one of the world\'s most advanced computer facilities. A former University of Phoenix faculty member, he has taught IT management at UCLA and California State University, Los Angeles (CSULA). nbsp; informit.com/ph nbsp; nbsp;',
#        'Learn the interviewing skills you need now with Interviewer Success!  The importance of proper interviewing techniques should not be understated. Recruiting has an impact on revenue, strategic goals, competitive advantage and organizational success. Success in these areas is paramount to having a healthy and successful business. Your role as an interviewer is extremely important, so you must know how to do this job well.   Interviewer Success allows you to quickly learn how to find out the information you need to know about a candidate to make a good hiring decision. You’ll learn how to review a résumé, how to prepare for an interview, what you can and cannot legally ask a candidate, behavioral interviewing techniques and much more!',
#        'A Primer on the HL7 Version 3 Healthcare Interoperability Standard ',
#        'The CDA book provides clear and easy to use guidance to implement the standard, with numerous examples covering many of the nuances of the standard.\xa0Readers can learn not only how to implement healthcare IT using the CDA standard, but to "speak" in the language of the standard, and to understand its idioms.',
#        "Why can't you get what you really want from IT? All you desire is a ready-and-willing partner to help you exploit IT to drive your business. Instead, you get endless rules and regulations, not to mention processes, projects, and technologies that deliver too little, too late, for too much. It's frustrating!How to build a relationship that puts you firmly in control and produces the business results you need? In The 8 Things We Hate About IT, Susan Cramm provides the answers.Start by understanding differences between operational and IT managers - in backgrounds, personality, pressures, and incentives. Cramm explains how differences prevent operational managers and IT from communicating what, why, and how they do what they do.Citing case studies and stories, the author then presents practical strategies for overcoming the difficulty. These include seeing things from your IT partners' perspective, developing a single version of 'truth,' and assuming accountability for IT just as you've done for management of your firm's financial and human resources.Brutally honest, provocative, and filled with sound advice, this book reveals that the key to solving the IT problem is decidedly un-IT: it's a deeper understanding of human behavior, including how to apply your leadership skills to the world of IT.",
#        'Until now, design patterns for the MapReduce framework have been scattered among various research papers, blogs, and books. This handy guide brings together a unique collection of valuable MapReduce patterns that will save you time and effort regardless of the domain, language, or development framework you’re using.Each pattern is explained in context, with pitfalls and caveats clearly identified to help you avoid common design mistakes when modeling your big data architecture. This book also provides a complete overview of MapReduce that explains its origins and implementations, and why design patterns are so important. All code examples are written for Hadoop.Summarization patterns: get a top-level view by summarizing and grouping data Filtering patterns: view data subsets such as records generated from one user Data organization patterns: reorganize data to work with other systems, or to make MapReduce analysis easier Join patterns: analyze different datasets together to discover interesting relationships Metapatterns: piece together several patterns to solve multi-stage problems, or to perform several analytics in the same job Input and output patterns: customize the way you use Hadoop to load or store data ""A clear exposition of MapReduce programs for common data processing patterns—this book is indespensible for anyone using Hadoop."" --Tom White, author of Hadoop: The Definitive Guide',
#        'Google Executive Chairman and ex-CEO Eric Schmidt and former SVP of Products Jonathan Rosenberg came to Google over a decade ago as proven technology executives. At the time, the company was already well-known for doing things differently, reflecting the visionary--and frequently contrarian--principles of founders Larry Page and Sergey Brin. If Eric and Jonathan were going to succeed, they realized they would have to relearn everything they thought they knew about management and business. Today, Google is a global icon that regularly pushes the boundaries of innovation in a variety of fields. HOW GOOGLE WORKS is an entertaining, page-turning primer containing lessons that Eric and Jonathan learned as they helped build the company. The authors explain how technology has shifted the balance of power from companies to consumers, and that the only way to succeed in this ever-changing landscape is to create superior products and attract a new breed of multifaceted employees whom Eric and Jonathan dub "smart creatives." Covering topics including corporate culture, strategy, talent, decision-making, communication, innovation, and dealing with disruption, the authors illustrate management maxims ("Consensus requires dissension," "Exile knaves but fight for divas," "Think 10X, not 10%") with numerous insider anecdotes from Google\'s history, many of which are shared here for the first time.In an era when everything is speeding up, the best way for businesses to succeed is to attract smart-creative people and give them an environment where they can thrive at scale. HOW GOOGLE WORKS explains how to do just that.',
#        "How did salesforce.com grow from a start up in a rented apartment into the world's fastest growing software company in less than a decade? For the first time, Marc Benioff, the visionary founder, chairman and CEO of salesforce.com, tells how he and his team created and used new business, technology, and philanthropic models tailored to this time of extraordinary change. Showing how salesforce.com not only survived the dotcom implosion of 2001, but went on to define itself as the leader of the cloud computing revolution and spark a $46-billion dollar industry, Benioff's story will help business leaders and entrepreneurs stand out, innovate better, and grow faster in any economic climate.In Behind the Cloud, Benioff shares the strategies that have inspired employees, turned customers into evangelists, leveraged an ecosystem of partners, and allowed innovation to flourish.",
#        "Employees are your company's number one asset. Hiring the Best offers managers and HR personnel a proven and practical approach to recruiting and selecting the right people for the job. With over 400 questions you can use to interview candidates and obtain the most pertinent information, you'll be armed with the tools you need to ensure that you are indeed Hiring the Best.Completely revised and updated! Updates include new section on electronic recruitment, revised resource section, and information about law and guidelines that influence hiring practices.Hiring the Best allows you to determine not only if candidates can do the job, but also if they can be managed effectively and thrive in their new positions.",
#        "SummarySolr in Action is a comprehensive guide to implementing scalable search using Apache Solr. This clearly written book walks you through well-documented examples ranging from basic keyword searching to scaling a system for billions of documents and queries. It will give you a deep understanding of how to implement core Solr capabilities.About the BookWhether you're handling big (or small) data, managing documents, or building a website, it is important to be able to quickly search through your content and discover meaning in it. Apache Solr is your tool: a ready-to-deploy, Lucene-based, open source, full-text search engine. Solr can scale across many servers to enable real-time queries and data analytics across billions of documents.Solr in Action teaches you to implement scalable search using Apache Solr. This easy-to-read guide balances conceptual discussions with practical examples to show you how to implement all of Solr's core capabilities. You'll master topics like text analysis, faceted search, hit highlighting, result grouping, query suggestions, multilingual search, advanced geospatial and data operations, and relevancy tuning.This book assumes basic knowledge of Java and standard database technology. No prior knowledge of Solr or Lucene is required.Purchase of the print book includes a free eBook in PDF, Kindle, and ePub formats from Manning Publications.What's InsideHow to scale Solr for big dataRich real-world examplesSolr as a NoSQL data storeAdvanced multilingual, data, and relevancy tricksCoverage of versions through Solr 4.7About the AuthorsTrey Grainger is a director of engineering at CareerBuilder. Timothy Potter is a senior member of the engineering team at LucidWorks. The authors work on the scalability and reliability of Solr, as well as on recommendation engine and big data analytics technologies.Table of ContentsPART 1  MEET SOLRIntroduction to SolrGetting to know Solr Key Solr concepts Configuring Solr Indexing Text analysis PART 2  CORE SOLR CAPABILITIESPerforming queries and handling resultsFaceted searchHit highlightingQuery suggestionsResult grouping/field collapsingTaking Solr to productionPART 3  TAKING SOLR TO THE NEXT LEVELSolrCloudMultilingual searchComplex query operationsMastering relevancy",
#        "Winner-2010 National Staff Development Council's Staff Development Book of the Year AwardBronze Medal Award Winner-ForeWord Reviews 2009 Book of the Year AwardBuilding a Professional Learning Community at WorkTM: A Guide to the First Year addresses the real-world critical questions that arise when schools begin their work to become professional learning communities. How can administrators and teachers take the promise of a PLC and turn it into reality? How can school leaders transform theories of collaboration into highly effective nuts-and-bolts practices? This book is set in the context of one year in the life of a PLC. It chronicles the efforts of a building principal, Steve, and his teachers to build a true PLC at Central Middle School by focusing on the successes and challenges inherent in the process. Each chapter includes four elements. An opening story highlights an important event in the growth of a learning community. Lessons From the Front Line spotlights the successful decisions and common mistakes made by the characters in the opening story. The Relevant Theory and Research section introduces the theories of experts and connects them to the work of PLCs to provide readers with an approachable framework for understanding and a language for describing the complex, yet predictable, changes that are inevitable when schools restructure as PLCs. The Recommendations section offers a collection of suggestions from which to draw while working through change in a building. The lessons in Building a Professional Learning Community at Work are drawn from the authors own experiences working as teachers, building administrators, consultants, and coaches at the elementary, middle, and high school levels. It emphasizes that powerful collaboration can happen anywhere, but it requires hard work, purposeful steps, and a deep understanding of the PLC model. The tools in this book have been tested time and again by real teachers and teams.",
#        'For one-semester undergraduate and graduate level courses in Organizational Behavior.  This title is a Pearson Global Edition.  The Editorial team at Pearson has worked closely with educators around the world to include content which is especially relevant to students outside the United States. Concise fundamentals for students. Ultimate flexibility for instructors.  This bestselling, brief alternative for the OB course covers all the key concepts needed to understand, predict, and respond to the behavior of people in real-world organizations. This text also includes cutting-edge topics and streamlined pedagogy to allow maximum flexibility in designing and shaping your course.  The eleventh edition contains expanded and updated coverage on international issues, as well as new sections on the management of information, safety and emotions at work, risk aversion, self-determination theory, managing information, and downsizing. Accompanied by mymanagementlab! See the hands in the air, hear the roar of discussion - be a rock star in the classroom. mymanagementlab makes it easier for you to rock the classroom by helping you hold students accountable for class preparation, and getting students engaged in the material through an array of relevant teaching and media resources. Visit mymanagementlab.com for more information.',
#        'The only book to take an in-depth look at deploying Hyper-V Now in its second generation, the popular Hyper-V boasts technical advances that create even more dynamic systems than ever before. This unique resource serves an authoritative guide to deploying Windows Server 2008 R2 Hyper-V comprehensively. Step-by-step instructions demonstrate how to design a Hyper-V deployment, build a Hyper-V host environment, and design a management system with System Center Virtual Machine Manager 2008 R2. Features real-world examples that show you how to design a Hyper-V deployment, build a Hyper-V host environment, and design a management system Walks you through incorporating System Center Operations Manager 2008 R2, System Center Data Protection Manager 2010, and System Center Essentials 2010 Offers authoritative coverage of Hyper-V security, business continuity, and an array of VM roles, including domain controllers, Exchange Server, SQL Server, and System Center This in-depth guide is the ultimate resource for system administrators, engineers, and architects, and IT consultants deploying Hyper-V.',
#        'Electronic payment is the economic backbone of all e-commerce transactions. This book covers the major subjects related to e-payment such as, for example, public key infrastructure, smart cards, payment agents, digital cash, SET protocols, and micro-payment. Its first part covers the infrastructure for secure e-payment over the Internet, whereas in the second part a variety of e-payment methods and systems are described.  This edited volume offers a well-written and sound technical overview of the state of the art in e-payment for e-business developers, graduate students, and consultants. It is also ideally suited for classes and training courses in e-commerce or e-payment.',
#        "Are you an architect? Scrum Master? team leader? project manager? If you are any of these, you will find that leadership, done right, is a very tough job. This book deals with the hard parts. Not with tools, but with people.  Here is the manifesto that drives this book:   For us as team leaders, the goal and the way we measure our work is the overall growth in skills of self-organization and self-maintenance in each member of our team and the team as a whole.   To that end:  • We accept that the team's needs from us change continuously based on their skills for handling the current reality of work, so we embrace a continuously changing leadership style over a one-style-fits-all leadership approach. • We believe in challenging ourselves and our teams to always get better, so: •     * We create slack time for the team to learn and be challenged. •     * We embrace taking risks for our team over staying safe. •     * We embrace fear and discomfort while learning new skills over keeping people within their comfort zone. •     * We embrace experimentation as a constant practice over maintaining the status quo: •         * With people •         * With tools •         * With processes •         * With the environment • * We believe our core practice is leading people, not wielding machines, so: •     * We embrace spending more time with our team than in meetings.  •     * We embrace treating software problems as people problems.  •     * We learn people skills and communication techniques.  About the notes The second part of this book allows a peek into the minds of some of the best leaders, consultants, and managers as they give advice to a new team leader. Hear from Johanna Rothman, Kevlin Henney, Dan North, Uncle Bob Martin, and many others about the one thing they would like to teach you if you ever become a team leader, Scrum Master, project manager, or architect.",
#        'This is the official curriculum of the Apple Yosemite 101: OS X Support Essentials 10.10 course and preparation for Apple Certified Support Professional (ACSP) 10.10 certification–as well as a top-notch primer for anyone who needs to support, troubleshoot, or optimize OS X Yosemite. This guide provides comprehensive coverage of Yosemite and is part of the Apple Pro Training series–the only Apple-certified books the market. Designed for support technicians, help desk specialists, and ardent Mac users, this guide takes you deep inside the Yosemite operating system. Readers will find in-depth, step-by-step instruction on everything from installing and configuring Yosemite to managing networks and system administration. Whether you run a computer lab or an IT department, you’ll learn to set up users, configure system preferences, manage security and permissions, use diagnostic and repair tools, troubleshoot peripheral devices, and more–all on your way to preparing for the industry-standard ACSP certification.    Covers updated system utilities and new features of OS X Yosemite. Features authoritative explanations of underlying technologies, troubleshooting, system administration, and much more. Focused lessons take you step by step through practical, real-world tasks. Lesson files and bonus material available for download–including lesson review questions summarizing what you’ve learned to prepare you for the Apple certification exam.   \xa0',
#        'Simple, powerful marketing strategies every business can afford to implementThere\'s never been a better time to be a marketer or entrepreneur than right now. Thanks to the Internet, a new world of free and inexpensive tactics can help get the word out to the prospects of any business with a limited marketing budget. Free Marketing delivers more than 100 ideas to help any small business owner or marketer generate new revenue--with little or no marketing budget.With both Internet-based and creative offline ideas, you\'ll discover ways to turn your top customers into your unpaid sales force, get your competitors to help you promote your new products, grow a loyal audience that devours your content, and spread the word about any product, service, cause or personality.Use simple videos as promotional power toolsHold an eBay auction for publicity purposes (author Jim Cockrum made over $30,000 and earned tons of free publicity from just one auction)Find the perfect online partners that can take you to the next level quickly...and more!Grow a successful business without letting your marketing budget tell you "No." Jim Cockrum has proven that the most powerful marketing strategies are the cheapest.',
# ...
#        'Thorough coverage of the improvements and changes to SharePoint 2010 SharePoint 2010 boasts a variety of incredible new features that will challenge even the most experienced administrator who is upgrading from SharePoint 2007. Written by a team of SharePoint experts, this book places a takes aim at showing you how to make these new features work right for you. Offering an in-depth look at SharePoint 2010, the authors focus on how SharePoint functionality has changed from its earliest version to its newest, and they provide you with detailed coverage of all the new features and capabilities.  Presents in-depth coverage of the new features and functions of SharePoint 2010 Demonstrates installation, configuration, and upgrading existing SharePoint 2007 servers Discusses architecture and capacity planning, securing and managing site content, and integrating Office clients Details the protocol for handling monitoring, creating backups, and executing disaster recovery Addresses shared service applications, navigation and governance, and business intelligence and reporting services  Professional SharePoint 2010 presents a solid understanding of the functionality that SharePoint 2010 provides, which will allow you to see what it can do for you.',
#        "Get a Jump Start on building applications with Bootstrap today!Originally developed by Twitter, Bootstrap is a framework that making the once-arduous process of crafting fully responsive web designs a breeze! Discover why Bootstrap is fast becoming a favorite tool of top web designers.In just one weekend with this hands-on tutorial, you'll learn how to:Integrate Bootstrap into your projectsUnderstand the basic Bootstrap templateWork with Bootstrap's gridCustomize Bootstrap to work with any project",
#        'Over the past 10 years, distributed systems have become more fine-grained. From the large multi-million line long monolithic applications, we are now seeing the benefits of smaller self-contained services. Rather than heavy-weight, hard to change Service Oriented Architectures, we are now seeing systems consisting of collaborating microservices. Easier to change, deploy, and if required retire, organizations which are in the right position to take advantage of them are yielding significant benefits.This book takes an holistic view of the things you need to be cognizant of in order to pull this off. It covers just enough understanding of technology, architecture, operations and organization to show you how to move towards finer-grained systems.',
#        'You can choose several data access frameworks when building Java enterprise applications that work with relational databases. But what about big data? This hands-on introduction shows you how Spring Data makes it relatively easy to build applications across a wide range of new data access technologies such as NoSQL and Hadoop.Through several sample projects, you’ll learn how Spring Data provides a consistent programming model that retains NoSQL-specific features and capabilities, and helps you develop Hadoop applications across a wide range of use-cases such as data analysis, event stream processing, and workflow. You’ll also discover the features Spring Data adds to Spring’s existing JPA and JDBC support for writing RDBMS-based data access layers.Learn about Spring’s template helper classes to simplify the use of database-specific functionality Explore Spring Data’s repository abstraction and advanced query functionality Use Spring Data with Redis (key/value store), HBase (column-family), MongoDB (document database), and Neo4j (graph database) Discover the GemFire distributed data grid solution Export Spring Data JPA-managed entities to the Web as RESTful web services Simplify the development of HBase applications, using a lightweight object-mapping framework Build example big-data pipelines with Spring Batch and Spring Integration ',
#        'David Meerman Scotts marketing bible has become a modern day business classic.This is the book every ambitious, forward-thinking, progressive marketer or publicist has at the front of their shelf. Business communication has changed over the recent years. Creative ad copy is no longer enough. The New Rules of Marketing and PR has brought thousands of marketers up to speed on the changing requirements of promoting products or services in the new digital age. This is a one-of-a-kind, pioneering guide, offering a step-by-step action plan for harnessing the power of the Internet to communicate with buyers directly, raise online visibility, and increase sales. Its about getting the right message to the right people at the right time - for a fraction of the cost of a big-budget advertising campaign. This new, updated edition includes:A new introduction discussing recent changes to the world of marketing and PRA brand new chapter on mobile marketingAn additional chapter on real-time marketing and PRUpdated information on how to measure the success of your campaignsA range of new toolsFresh case studies',
#        "Microsoft's Windows Presentation Foundation (WPF) provides the foundation for building applications and high-quality user experiences for the Windows operating system. It blends the application user interface, documents, and media content, while exploiting the full power of your computer's operating system. Its functionality extends to the support for tablet PCs and other forms of input device, and it provides a more modern imaging and printing pipeline, accessibility and UI automation infrastructure, data-driven user interfaces and visualization, and integration points for weaving the application experience into the Windows shell.  This book shows you how WPF really works. It provides you with the no-nonsense, practical advice that you need in order to build high-quality WPF applications quickly and easily. After giving you a firm foundation, it goes on to explore the more advance aspects of WPF and how they relate to the others elements of the .NET 4.0 platform and associated technologies such as Silverlight.",
#        '"As someone who uses jQuery on a regular basis, it was surprising to discover how much of the library I’m not using. This book is indispensable for anyone who is serious about using jQuery for non-trivial applications."-- Raffaele Cecco, longtime developer of video games, including Cybernoid, Exolon, and StormlordjQuery is the "write less, do more" JavaScript library. Its powerful features and ease of use have made it the most popular client-side JavaScript framework for the Web. Ideal for JavaScript developers at all skill levels, this book is jQuery\'s trusty companion: the definitive "read less, learn more" guide to the library.jQuery Pocket Reference explains everything you need to know about jQuery, completely and comprehensively. You\'ll learn how to:Select and manipulate document elementsAlter document structureHandle and trigger eventsCreate visual effects and animationsScript HTTP with Ajax utilitiesUse jQuery\'s selectors and selection methods, utilities, plugins and moreThe 25-page quick reference summarizes the library, listing all jQuery methods and functions, with signatures and descriptions.',
#        '*Would you like to use a consistent visual notation for drawing integration solutions? Look inside the front cover. *Do you want to harness the power of asynchronous systems without getting caught in the pitfalls? See "Thinking Asynchronously" in the Introduction. *Do you want to know which style of application integration is best for your purposes? See Chapter 2, Integration Styles. *Do you want to learn techniques for processing messages concurrently? See Chapter 10, Competing Consumers and Message Dispatcher. *Do you want to learn how you can track asynchronous messages as they flow across distributed systems? See Chapter 11, Message History and Message Store. *Do you want to understand how a system designed using integration patterns can be implemented using Java Web services, .NET message queuing, and a TIBCO-based publish-subscribe architecture? See Chapter 9, Interlude: Composed Messaging.  Utilizing years of practical experience, seasoned experts Gregor Hohpe and Bobby Woolf show how asynchronous messaging has proven to be the best strategy for enterprise integration success. However, building and deploying messaging solutions presents a number of problems for developers.Enterprise Integration Patterns provides an invaluable catalog of sixty-five patterns, with real-world solutions that demonstrate the formidable of messaging and help you to design effective messaging solutions for your enterprise.  The authors also include examples covering a variety of different integration technologies, such as JMS, MSMQ, TIBCO ActiveEnterprise, Microsoft BizTalk, SOAP, and XSL. A case study describing a bond trading system illustrates the patterns in practice, and the book offers a look at emerging standards, as well as insights into what the future of enterprise integration might hold.  This book provides a consistent vocabulary and visual notation framework to describe large-scale integration solutions across many technologies. It also explores in detail the advantages and limitations of asynchronous messaging architectures. The authors present practical advice on designing code that connects an application to a messaging system, and provide extensive information to help you determine when to send a message, how to route it to the proper destination, and how to monitor the health of a messaging system.If you want to know how to manage, monitor, and maintain a messaging system once it is in use, get this book. 0321200683B09122003',
#        "Do you want to sound more like a native speaker of English? You need the key phrases and the conversational tools native speakers use to get their message across. Collins Speaking will help you become a confident and fluent speaker of English by choosing the right words, pronunciation and tone. Learn how to start up conversations, keep conversations going and deal with difficult situations. Includes practice on: * starting conversations  * interrupting  * making suggestions  * giving and receiving compliments  * asking for and giving opinions  * saying no politely Collins Speaking is part of the new English for Life series and uses authentic material from the Collins Corpus, the world's largest database of the English language. It is suitable for self-study and classroom use, and can help towards Cambridge FCE preparation. Suitable for Intermediate learners of English (CEF level B1+).",
#        ' Compiling for the .NET Common Language Runtime gives software engineers critical information for creating .NET compilers or implementing .NET programming languages. Renowned compiler expert John Gough goes ¿under the hood¿ with CLR, illuminating its key concepts and covering every facet of its architecture and behavior. Gough presents extensive examples, many drawn from C# and Gough¿s own open source Gardens Point Component Pascal compiler.',
#        'Each of the 180 grammar topics is organized into 2-page sections Explains how the grammar for each topic is used and how to avoid mistakes Includes a tip to help students sound more natural Covers the topics students need to know for the Cambridge ESOL exams (FCE, CAE and CPE).',
#        "The visionary CEO of Zappos explains how an emphasis on corporate culture can lead to unprecedented  success. Pay new employees $2000 to quit. Make customer service the entire company, not just a department. Focus  on company culture as the #1 priority. Apply research from the science of happiness to running a business.  Help employees grow both personally and professionally. Seek to change the world. Oh, and make money  too. Sound crazy? It's all standard operating procedure at Zappos.com, the online retailer that's doing over  $1 billion in gross merchandise sales every year. In 1999, Tony Hsieh (pronounced Shay) sold LinkExchange, the company he co-founded, to Microsoft for $265  million. He then joined Zappos as an adviser and investor, and eventually became CEO. In 2009, Zappos was listed as one of Fortune magazine's top 25 companies to work for, and was acquired by  Amazon later that year in a deal valued at over $1.2 billion on the day of closing. In his first book, Tony shares the different business lessons he learned in life, from a lemonade stand  and pizza business through LinkExchange, Zappos, and more. Ultimately, he shows how using happiness as a  framework can produce profits, passion, and purpose both in business and in life. (edited by author)",
#        "Build high-performing teams with an evidence-based framework that delivers results             Committed Teams: Three Steps to Inspiring Passion and Performance is based on a deceptively simple philosophy: set a direction, try to stay on track, and make adjustments when necessary. \xa0Easy to do? \xa0Hardly--especially when the typical workday is time-crunched, stressful, and deadline-driven. \xa0Drawing on research done at the Wharton School of Business, the authors reveal how to deliver results under these tough conditions.\xa0Tested and refined in Wharton's Executive Development Program, Committed Teams will help you gain buy-in for shared objectives, assign roles to the right people, and establish norms for effective collaboration. \xa0Whether your team aims to execute a strategy, produce breakthrough innovations, collaborate across global boundaries, or launch a new venture, this how-to guide offers the pragmatic advice you need. \xa0Engaging stories and illustrative examples from business, entertainment, sports, and the arts bring the three-step process to life.\xa0This game-changing book provides the tools for:Aligning every member of your team behind a motivating visionMaking team meetings efficient and productiveClosing the gap between stated goals and actual behaviors\xa0If you want to be competitive in a demanding, fast-paced work environment, you need to rely on a high-performing team. \xa0Committed Teams is the indispensable resource for creating one."],
#       dtype=object)

# %% [markdown]
# ## Data preprocessing

# %%
string = "hey you, I say hello, so hello to you."
vocab = string.split(' ')
vocab
# Out:
# ['hey', 'you,', 'I', 'say', 'hello,', 'so', 'hello', 'to', 'you.']

# %% [markdown]
# ### Filter out noise symbols
# Because of the way we tokenize our corpus (using white space as a seperator), noise symbols like " , . ' ( ) [ ] { } : ; - can really mess-up our vocab library because
#
#     hello != hello, != "hello != hello.

# %%
token = tf.keras.preprocessing.text.Tokenizer(num_words=None, filters='!"#$%&()*,-./:;<=>?@[\\]^_`{|}~\t\n',)
token.fit_on_texts(corpus)
corpus = token.sequences_to_texts(token.texts_to_sequences(corpus))

# %%
corpus[:2]
# Out:
# ['companies of all sizes are finding an urgent new priority keeping employees this book takes the reader through the critical ideas of employee retention using what is called the three rs of employee retention respect recognition and rewards as the basis for any program designed to keep people around',
#  "written by a software developer for software developers this book is a unique collection of the latest software development methods the author includes ood uml design patterns agile and xp methods with a detailed description of a complete software design for reusable programs in c++ and java using a practical problem solving approach it shows how to develop an object oriented application—from the early stages of analysis through the low level design and into the implementation walks readers through the designer's thoughts — showing the errors blind alleys and creative insights that occur throughout the software design process the book covers statics and dynamics principles of class design complexity management principles of package design analysis and design patterns and paradigm crossings explains the principles of ood one by one and then demonstrates them with numerous examples completely worked through designs and case studies covers traps pitfalls and work arounds in the application of c++ and ood and then shows how agile methods can be used discusses the methods for designing and developing big software in detail features a three chapter in depth single case study of a building security system for software engineers programmers and analysts who want to understand how to design object oriented software with state of the art methods"]

# %% [markdown]
# ### Filter out stopwords
# Stopwords are words that consider to be unimportant in a document because they are just too common.
#
# Example of stopwords include: *__is, am, are, the, which, what, how, at, on, has, have, etc...__*

# %%
stop_words = stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
for idx, description in enumerate(corpus):
    tokenized_description = word_tokenize(description)
    new_description = [w for w in tokenized_description if not w in stop_words]
    corpus[idx] = " ".join(new_description)

# %%
corpus
# Out:
# ['companies sizes finding urgent new priority keeping employees book takes reader critical ideas employee retention using called three rs employee retention respect recognition rewards basis program designed keep people around',
#  "written software developer software developers book unique collection latest software development methods author includes ood uml design patterns agile xp methods detailed description complete software design reusable programs c++ java using practical problem solving approach shows develop object oriented application—from early stages analysis low level design implementation walks readers designer 's thoughts — showing errors blind alleys creative insights occur throughout software design process book covers statics dynamics principles class design complexity management principles package design analysis design patterns paradigm crossings explains principles ood one one demonstrates numerous examples completely worked designs case studies covers traps pitfalls work arounds application c++ ood shows agile methods used discusses methods designing developing big software detail features three chapter depth single case study building security system software engineers programmers analysts want understand design object oriented software state art methods",
#  "texts must interesting enough students want read language otherwise expect students want read english authors ' golden rule choose texts topics every level american english file ensures get material learners enjoy reading want talk texts 'could live without money ' really help generate opinion discussion create desire communicate created desire american english file helps develop learners ' communication skills one way strong focus pronunciation research shows poor pronunciation major contributor breakdowns communication jennifer jenkins phonology english international language american english file integrates pronunciation every lesson 'little often ' approach 's unique english file sounds chart puts picture sound phonetic alphabet learners find easier remember sounds ultimately improve pronunciation",
#  "table content section 1 1 career 2 getting started bang n't everyone else 3 thinking future goals 4 people skills need think 5 hacking interview 6 employment options enumerate choices 7 kind software developer 8 companies equal 9 climbing corporate ladder 10 professional 11 freedom quit job 12 freelancing going 13 creating first product 14 want start startup 15 working remotely survival strategies 16 fake till make 17 resumes boring let 's fix 18 n't get religious technology section 2 marketing 19 marketing basics code monkeys 20 building brand gets noticed 21 creating wildly successful blog 22 primary goal add value others 23 using social networks 24 speaking presenting training speak geek 25 writing books articles attract following 26 n't afraid look like idiot section 3 learning 27 learning learn teach 28 10 step process 29 steps 1 6 30 steps 7 10 repeat 31 looking mentors finding yoda 32 taking apprentice yoda 33 teaching learn want teach must",
#  'nassim nicholas taleb bestselling author black swan one foremost thinkers time reveals thrive uncertain world human bones get stronger subjected stress tension rumors riots intensify someone tries repress many things life benefit stress disorder volatility turmoil taleb identified calls “ antifragile ” category things gain chaos need order survive flourish black swan taleb showed us highly improbable unpredictable events underlie almost everything world antifragile taleb stands uncertainty head making desirable even necessary proposes things built antifragile manner antifragile beyond resilient robust resilient resists shocks stays antifragile gets better better furthermore antifragile immune prediction errors protected adverse events city state better nation state debt bad call “ efficient ” efficient government responses social policies protect strong hurt weak write resignation letter even starting job sinking titanic save lives book spans innovation trial error life decisions politics urban planning war personal finance economic systems medicine throughout addition street wisdom fat tony brooklyn voices recipes ancient wisdom roman greek semitic medieval sources loud clear antifragile blueprint living black swan world erudite witty iconoclastic taleb ’ message revolutionary antifragile antifragile make praise antifragile “ ambitious thought provoking highly entertaining ” —the economist “ bold book explaining embrace uncertainty randomness error may change lives ” —newsweek “ revelatory taleb pulls reader along logic socrates ” —chicago tribune “ startling richly crammed insights stories fine phrases intriguing asides read ” —matt ridley wall street journal “ trenchant persuasive taleb ’ insatiable polymathic curiosity knows bounds finish book feeling braver uplifted ” —new statesman “ antifragility ’ sound economic political doctrine ’ also key good life ” —fortune “ thought provoking brilliant ” —los angeles timesfrom hardcover edition',
#  'extreme programming ideal many software shops would love reach constant pressures produce software quickly actually implement agile software process allows company implement extreme programming quickly immediately begin producing software incrementally little 30 days implementing extreme programming easier said done process time consuming actually slow current software projects process book shows readers use scrum agile software development process quickly seamlessly implement xp shop still producing actual software using scrum agile process virtually eliminate downtime xp implementation',
#  "edition provides comprehensive approach investments fundamentals needed success cfp exam advanced topics readers learn make solid real investment decisions applications updated 'financial advisor 's investment case ' end chapter latest internet assignments",
#  "culture leadership ability change determine organizational performance 75 organizational change programs fail conceptual organization wide command control like 's change consultant marcella bremer developed pragmatic approach organizational culture change leadership starting point validated organizational culture assessment instrument based competing values framework professors kim cameron robert quinn next bremer shows engage people ocai workshops change circles peer groups 10 coworkers develop change plan teams also personal focused specific behaviors change circles 10 use mechanism copy coach correct within groups help organization members implement change develop behaviors make difference book pragmatic user ’ guide organizational culture change learn best practices change consultant unleash organization",
#  "business plus three level integrated skills business english course a1 false beginner b1 pre intermediate levels level student 's book 10 units designed easy enjoyable teach unit features integrated skills language practice units also include cultural awareness sections connect learners region beyond addition toeic style practice sections allow students ' progress measured",
#  'textbook adopts unique approach helping developers cs students learn hadoop mapreduce programming fast rather filled disjointed piecemeal code snippets show hadoop mapreduce programming features one time designed place total hadoop mapreduce programming learning process common application context mining customer spending patterns ensconced large volumes credit card transaction record data precise end end procedures given help set hadoop mapreduce development environment quickly eclipse maven mac os x step step procedures also given set four node linux cluster minimum run mapreduce programs local mode mac os x machine also fully distributed mode real cluster fact mapreduce programs presented book tested verified local mode linux cluster textbook mainly focuses teaching hadoop mapreduce programming scientific objective quantitative approach rather heavily relying subjective verbose sometimes even pompous textual descriptions sparse code snippets textbook uses hadoop java apis hadoop configuration parameters complete mapreduce programs execution logs outputs demonstrate hadoop mapreduce framework works write mapreduce programs specifically text covers following subjects introduction hadoop setting linux hadoop cluster hadoop distributed filesystem mapreduce job orchestration workflows basic mapreduce programming advanced mapreduce programming hadoop streaming hadoop administrationno matter role play team text help gain truly applicable hadoop skills effective efficient manner book also used supplementary textbook distributed computing hadoop course offered upper division college cs students',
#  "highly successful security book returns new edition completely updatedweb applications front door organizations exposing attacks may disclose personal information execute fraudulent transactions compromise ordinary users practical book completely updated revised discuss latest step step techniques attacking defending range ever evolving web applications 'll explore various new technologies employed web applications appeared since first edition review new attack techniques developed particularly relation client side reveals overcome new technologies techniques aimed defending web applications attacks appeared since previous editiondiscusses new remoting frameworks html5 cross domain integration techniques ui redress framebusting http parameter pollution hybrid file attacks morefeatures companion web site hosted authors allows readers try attacks described gives answers questions posed end chapter provides summarized methodology checklist tasksfocusing areas web application security things changed recent years book current resource critical topic discovering exploiting preventing web application security flaws",
#  "practical guide software developers different software architecture books 's teaches risk driven architecting need meticulous designs risks small excuse sloppy designs risks threaten success book describes way enough architecture avoids one size fits process tar pit advice tune design effort based risks face democratizes architecture book seeks make architecture relevant software developers developers need understand use constraints guiderails ensure desired outcomes seemingly small changes affect system 's properties cultivates declarative knowledge difference able hit ball knowing able hit psychologists refer procedural knowledge versus declarative knowledge book make aware provide names concepts emphasizes engineering book focuses technical parts software development developers ensure system works job titles processes shows build models analyze architectures make principled design tradeoffs describes techniques software designers use reason medium large sized problems points learn specialized techniques detail provides practical advice software design decisions influence architecture vice versa approach book embraces drill pop behavior describing models various levels abstraction architecture data structure design",
#  'pro android 2 shows build real world fun mobile applications using google ’ latest android software development kit new edition updated android 2 covering everything fundamentals building applications embedded devices advanced concepts custom 3d components opengl touchscreens including gestures android development guides simply discuss topics pro android 2 offers combination expert insight real sample applications work discover design architecture android sdk practical examples build mobile applications using android sdk explore use android apis including media wi fi learn android 2 ’ integrated local web search handwriting gesture ui google translate text speech features pro android 2 dives deep providing knowledge techniques need build mobile applications ranging games google apps including add ons google docs ’ able extend run new google chrome apis g1 g2 next generation google phones android enabled devices ’ learn use android build java based mobile applications google phones touch screen keyboard thanks cupcake ’ inclusion android 1 5 design architect using google ’ latest android sdk use android sdk write mobile applications embedded devices create 3d graphics opengl custom components build multimedia game apps using android ’ media apis opengl use android ’ location based services networking wi fi apis security create allow integrated local web searches build handwriting gesture uis incorporate google translate android applications book book professional software engineers programmers looking move ideas applications mobile space android assumes readers passable understanding java including able write classes handle basic inheritance structures book also targets hobbyists table contents introducing android computing platform getting feet wet using resources content providers intents building user interfaces using controls working menus dialogs unveiling 2d animation exploring security location based services building consuming services using media framework telephony apis programming 3d graphics opengl managing organizing preferences exploring live folders home screen widgets android search exploring text speech translate apis touchscreens titanium mobile webkit based approach android development working android market outlook resources',
#  "five years 100 000 copies first published 's hard imagine anyone working web design n't read steve krug 's instant classic web usability people still discovering every day second edition steve adds three new chapters style original wry entertaining yet loaded insights practical advice novice veteran alike n't surprised completely changes way think web design three new chapters usability common courtesy people really leave web sites web accessibility css making sites usable accessible help boss wants surviving executive design whims thought usability enemy design read first edition book n't make think showed put position person uses site reading couple hours putting ideas work past five years say done improve abilities web designer book second edition steve krug adds essential ammunition whose bosses clients stakeholders marketing managers insist wrong thing design write program manage web sites must read book jeffrey zeldman author designing web standards",
#  'global outsourcing defined seamless integration onsite onshore nearshore offshore delivery teams rapidly becoming execution delivery strategy choice business process projects corporations today book goes beyond theory explain step step methodology managers follow execute global outsourcing strategy designed implementation manual global outsourcing discusses detailed tasks involved planning sourcing execution phases every project',
#  "alice 's adventures wonderland 1865 novel written english author charles lutwidge dodgson better known pseudonym lewis carroll tells story girl named alice falls rabbit hole fantasy world populated peculiar anthropomorphic creatures 1865 dodgson 's tale published alice 's adventures wonderland lewis carroll illustrations john tenniel first print run 2 000 destroyed tenniel objections print quality new edition released december year carrying 1866 date quickly printed reproduction edition",
#  'complex world products easy use win favor consumers first book topic simplicity aimed specifically interaction designers shows drill simplify user experiences designing digital tools applications begins explaining simplicity attractive explores laws simplicity presents proven strategies achieving simplicity remove hide organize displace become guidelines designers learn simplicity seeing examples case studies results speak',
#  "hibernate makes java based data persistence incredibly easy perform popular resources make hibernate technology darned impossible learn well learning hibernate n't hard anymore copy hibernate made easy side cameron mckenzie 's hibernate made easy finally brings light idea technology fun easy use also fun easy learn building upon simple straight forward examples make even difficult topics easy understand book explores key concepts absolutely must know order start effectively leveraging hibernate framework discarding old xml based hbm mapping files hibernate made easy show simplify designs leveraging hibernate jpa annotations together making applications manageable maintainable importantly faster easier develop fundamental create retrieve update delete operations mapping complex inheritance hierarchies hibernate made easy explains using friendly conversational style reads less like technical book like informative conversation hibernate expert examples book incredibly easy follow reproduce code errors book guaranteed concepts book help learn empower solve even daunting programming challenges managing transactions http based request response cycle implementing highly advanced data access objects daos java 5 generics book teach really need know java based persistence hibernate want learn hibernate want learn hibernate quickly want explained manner easy follow understand really choice get copy cameron mckenzie 's hibernate made easy today information check hiberbook com",
#  "asp net 4 principal standard creating dynamic web pages windows platform pro asp net 4 c 2010 raises bar high quality practical advice learning deploying microsoft 's dynamic web solution edition updated everything need master version 4 asp net including coverage asp net mvc asp net ajax 4 asp net dynamic data silverlight 3 seasoned net professionals matthew macdonald mario szpuszta explain get groundbreaking technologies cover asp net 4 whole illustrating newer features functionality carried previous versions asp book give knowledge need code real asp net 4 applications best possible style",
#  'matter much experience javascript odds ’ fully understand language part ’ know js series compact guide focuses new features available ecmascript 6 es6 latest version standard upon javascript built like books series ’ know js es6 beyond dives trickier parts language many javascript programmers either avoid know nothing armed knowledge achieve true javascript mastery book learn new es6 syntax eases pain points common programming idiomsorganize code iterators generators modules classesexpress async flow control promises combined generatorsuse collections work efficiently data structured waysleverage new api helpers including array object math number stringextend program ’ capabilities meta programmingpreview features likely coming js beyond es6',
#  "best practice guide managing infrastructures fully updated nbsp systems management minute guide maintaining stable responsive production environments top systems management expert rich schiesser illuminates theoretical practical aspects systems management using methods examples drawn decades experience leading consulting world 's complex enterprise organizations nbsp thoroughly updated edition covers every systems management disciplinenbsp elements success people process technology schiesser shows apply best practice system management throughout infrastructure environments mainframe data centers web enabled systems client server mid range platforms wireless voip networks nbsp nbsp schiesser systematically addresses today 's crucial issues well emerging trends transform systems management 'll find entirely new chapter using infrastructure library itil effectively plus new coverage ranging managing outsourced functions efficiently delivering ultra speed internet connections edition includes real life examples throughout new interactive problems designed give professionals even deeper insight coverage includes nbsp nbsp implementing bullet proof processes areas ranging change management production acceptance capacity planning storage nbsp optimizing people components service delivery customer service executive support nbsp using technology manage systems efficiently effectively nbsp systematically managing performance availability business continuity nbsp reducing cost complexity facilities management nbsp taking strategic approach security nbsp nbsp rich schiesser founded owns rws enterprises inc consultancy specializes designing implementing world class infrastructures client list included weather channel amazon com directv led major infrastructure organizations hughes aircraft city los angeles twentieth century fox nearly ten years managed primary data center northrop grumman one world 's advanced computer facilities former university phoenix faculty member taught management ucla california state university los angeles csula nbsp informit com ph nbsp nbsp",
#  'learn interviewing skills need interviewer success importance proper interviewing techniques understated recruiting impact revenue strategic goals competitive advantage organizational success success areas paramount healthy successful business role interviewer extremely important must know job well interviewer success allows quickly learn find information need know candidate make good hiring decision ’ learn review résumé prepare interview legally ask candidate behavioral interviewing techniques much',
#  'primer hl7 version 3 healthcare interoperability standard',
#  'cda book provides clear easy use guidance implement standard numerous examples covering many nuances standard readers learn implement healthcare using cda standard speak language standard understand idioms',
#  "ca n't get really want desire ready willing partner help exploit drive business instead get endless rules regulations mention processes projects technologies deliver little late much 's frustrating build relationship puts firmly control produces business results need 8 things hate susan cramm provides answers start understanding differences operational managers backgrounds personality pressures incentives cramm explains differences prevent operational managers communicating citing case studies stories author presents practical strategies overcoming difficulty include seeing things partners ' perspective developing single version 'truth ' assuming accountability 've done management firm 's financial human resources brutally honest provocative filled sound advice book reveals key solving problem decidedly un 's deeper understanding human behavior including apply leadership skills world",
#  'design patterns mapreduce framework scattered among various research papers blogs books handy guide brings together unique collection valuable mapreduce patterns save time effort regardless domain language development framework ’ using pattern explained context pitfalls caveats clearly identified help avoid common design mistakes modeling big data architecture book also provides complete overview mapreduce explains origins implementations design patterns important code examples written hadoop summarization patterns get top level view summarizing grouping data filtering patterns view data subsets records generated one user data organization patterns reorganize data work systems make mapreduce analysis easier join patterns analyze different datasets together discover interesting relationships metapatterns piece together several patterns solve multi stage problems perform several analytics job input output patterns customize way use hadoop load store data clear exposition mapreduce programs common data processing patterns—this book indespensible anyone using hadoop tom white author hadoop definitive guide',
#  "google executive chairman ex ceo eric schmidt former svp products jonathan rosenberg came google decade ago proven technology executives time company already well known things differently reflecting visionary frequently contrarian principles founders larry page sergey brin eric jonathan going succeed realized would relearn everything thought knew management business today google global icon regularly pushes boundaries innovation variety fields google works entertaining page turning primer containing lessons eric jonathan learned helped build company authors explain technology shifted balance power companies consumers way succeed ever changing landscape create superior products attract new breed multifaceted employees eric jonathan dub smart creatives covering topics including corporate culture strategy talent decision making communication innovation dealing disruption authors illustrate management maxims consensus requires dissension exile knaves fight divas think 10x 10 numerous insider anecdotes google 's history many shared first time era everything speeding best way businesses succeed attract smart creative people give environment thrive scale google works explains",
#  "salesforce com grow start rented apartment world 's fastest growing software company less decade first time marc benioff visionary founder chairman ceo salesforce com tells team created used new business technology philanthropic models tailored time extraordinary change showing salesforce com survived dotcom implosion 2001 went define leader cloud computing revolution spark 46 billion dollar industry benioff 's story help business leaders entrepreneurs stand innovate better grow faster economic climate behind cloud benioff shares strategies inspired employees turned customers evangelists leveraged ecosystem partners allowed innovation flourish",
#  "employees company 's number one asset hiring best offers managers hr personnel proven practical approach recruiting selecting right people job 400 questions use interview candidates obtain pertinent information 'll armed tools need ensure indeed hiring best completely revised updated updates include new section electronic recruitment revised resource section information law guidelines influence hiring practices hiring best allows determine candidates job also managed effectively thrive new positions",
#  "summarysolr action comprehensive guide implementing scalable search using apache solr clearly written book walks well documented examples ranging basic keyword searching scaling system billions documents queries give deep understanding implement core solr capabilities bookwhether 're handling big small data managing documents building website important able quickly search content discover meaning apache solr tool ready deploy lucene based open source full text search engine solr scale across many servers enable real time queries data analytics across billions documents solr action teaches implement scalable search using apache solr easy read guide balances conceptual discussions practical examples show implement solr 's core capabilities 'll master topics like text analysis faceted search hit highlighting result grouping query suggestions multilingual search advanced geospatial data operations relevancy tuning book assumes basic knowledge java standard database technology prior knowledge solr lucene required purchase print book includes free ebook pdf kindle epub formats manning publications 's insidehow scale solr big datarich real world examplessolr nosql data storeadvanced multilingual data relevancy trickscoverage versions solr 4 7about authorstrey grainger director engineering careerbuilder timothy potter senior member engineering team lucidworks authors work scalability reliability solr well recommendation engine big data analytics technologies table contentspart 1 meet solrintroduction solrgetting know solr key solr concepts configuring solr indexing text analysis part 2 core solr capabilitiesperforming queries handling resultsfaceted searchhit highlightingquery suggestionsresult grouping field collapsingtaking solr productionpart 3 taking solr next levelsolrcloudmultilingual searchcomplex query operationsmastering relevancy",
#  "winner 2010 national staff development council 's staff development book year awardbronze medal award winner foreword reviews 2009 book year awardbuilding professional learning community worktm guide first year addresses real world critical questions arise schools begin work become professional learning communities administrators teachers take promise plc turn reality school leaders transform theories collaboration highly effective nuts bolts practices book set context one year life plc chronicles efforts building principal steve teachers build true plc central middle school focusing successes challenges inherent process chapter includes four elements opening story highlights important event growth learning community lessons front line spotlights successful decisions common mistakes made characters opening story relevant theory research section introduces theories experts connects work plcs provide readers approachable framework understanding language describing complex yet predictable changes inevitable schools restructure plcs recommendations section offers collection suggestions draw working change building lessons building professional learning community work drawn authors experiences working teachers building administrators consultants coaches elementary middle high school levels emphasizes powerful collaboration happen anywhere requires hard work purposeful steps deep understanding plc model tools book tested time real teachers teams",
#  'one semester undergraduate graduate level courses organizational behavior title pearson global edition editorial team pearson worked closely educators around world include content especially relevant students outside united states concise fundamentals students ultimate flexibility instructors bestselling brief alternative ob course covers key concepts needed understand predict respond behavior people real world organizations text also includes cutting edge topics streamlined pedagogy allow maximum flexibility designing shaping course eleventh edition contains expanded updated coverage international issues well new sections management information safety emotions work risk aversion self determination theory managing information downsizing accompanied mymanagementlab see hands air hear roar discussion rock star classroom mymanagementlab makes easier rock classroom helping hold students accountable class preparation getting students engaged material array relevant teaching media resources visit mymanagementlab com information',
#  'book take depth look deploying hyper v second generation popular hyper v boasts technical advances create even dynamic systems ever unique resource serves authoritative guide deploying windows server 2008 r2 hyper v comprehensively step step instructions demonstrate design hyper v deployment build hyper v host environment design management system system center virtual machine manager 2008 r2 features real world examples show design hyper v deployment build hyper v host environment design management system walks incorporating system center operations manager 2008 r2 system center data protection manager 2010 system center essentials 2010 offers authoritative coverage hyper v security business continuity array vm roles including domain controllers exchange server sql server system center depth guide ultimate resource system administrators engineers architects consultants deploying hyper v',
#  'electronic payment economic backbone e commerce transactions book covers major subjects related e payment example public key infrastructure smart cards payment agents digital cash set protocols micro payment first part covers infrastructure secure e payment internet whereas second part variety e payment methods systems described edited volume offers well written sound technical overview state art e payment e business developers graduate students consultants also ideally suited classes training courses e commerce e payment',
#  "architect scrum master team leader project manager find leadership done right tough job book deals hard parts tools people manifesto drives book us team leaders goal way measure work overall growth skills self organization self maintenance member team team whole end • accept team 's needs us change continuously based skills handling current reality work embrace continuously changing leadership style one style fits leadership approach • believe challenging teams always get better • create slack time team learn challenged • embrace taking risks team staying safe • embrace fear discomfort learning new skills keeping people within comfort zone • embrace experimentation constant practice maintaining status quo • people • tools • processes • environment • believe core practice leading people wielding machines • embrace spending time team meetings • embrace treating software problems people problems • learn people skills communication techniques notes second part book allows peek minds best leaders consultants managers give advice new team leader hear johanna rothman kevlin henney dan north uncle bob martin many others one thing would like teach ever become team leader scrum master project manager architect",
#  'official curriculum apple yosemite 101 os x support essentials 10 10 course preparation apple certified support professional acsp 10 10 certification–as well top notch primer anyone needs support troubleshoot optimize os x yosemite guide provides comprehensive coverage yosemite part apple pro training series–the apple certified books market designed support technicians help desk specialists ardent mac users guide takes deep inside yosemite operating system readers find depth step step instruction everything installing configuring yosemite managing networks system administration whether run computer lab department ’ learn set users configure system preferences manage security permissions use diagnostic repair tools troubleshoot peripheral devices more–all way preparing industry standard acsp certification covers updated system utilities new features os x yosemite features authoritative explanations underlying technologies troubleshooting system administration much focused lessons take step step practical real world tasks lesson files bonus material available download–including lesson review questions summarizing ’ learned prepare apple certification exam',
#  "simple powerful marketing strategies every business afford implementthere 's never better time marketer entrepreneur right thanks internet new world free inexpensive tactics help get word prospects business limited marketing budget free marketing delivers 100 ideas help small business owner marketer generate new revenue little marketing budget internet based creative offline ideas 'll discover ways turn top customers unpaid sales force get competitors help promote new products grow loyal audience devours content spread word product service cause personality use simple videos promotional power toolshold ebay auction publicity purposes author jim cockrum made 30 000 earned tons free publicity one auction find perfect online partners take next level quickly grow successful business without letting marketing budget tell jim cockrum proven powerful marketing strategies cheapest",
#  'matter much experience javascript odds ’ fully understand language part ’ know js series concise yet depth guide focuses new asynchronous features performance techniques—including promises generators web workers—that let create sophisticated single page web applications escape callback hell process like books series ’ know js async performance dives trickier parts language many javascript programmers simply avoid armed knowledge become true javascript master book explore old new javascript methods handling asynchronous programmingunderstand callbacks let third parties control program ’ executionaddress inversion control issue javascript promisesuse generators express async flow sequential synchronous looking fashiontackle program level performance web workers simd asm jslearn valuable resources techniques benchmarking tuning expressions statements',
#  "comprehensive process defining software architectures work good software architecture foundation successful software system effective architecting requires clear understanding organizational roles artifacts activities performed optimal sequence performing activities process software architecting peter eeles peter cripps provide guidance challenges covering aspects architecting software system introducing best practice techniques apply every environment whether based java ee microsoft net technologies eeles cripps first illuminate concepts related software architecture including architecture documentation reusable assets next present accessible task focused guided tour typical project focusing architect 's role common issues illuminated addressed throughout finally conclude set best practices applied today 's complex systems come away book understanding role architect typical software development project document software architecture satisfy needs different stakeholders applicability reusable assets process architecting role architect respect requirements definition derivation architecture based set requirements relevance architecting creating complex systems process software architecting indispensable resource every working aspiring software architect every project manager software professional needs understand architecture influences work",
#  'first volume quality software management series gerald weinberg tackles first requirement developing quality software learning think correctly problems solutions quality guidelines management introduced stimulate kind thinking needed',
#  'fully revised updated installment bestselling author oz principle series two time new york times bestselling authors roger connors tom smith show leaders achieve record breaking results quickly effectively shaping organizational culture capitalize greatest asset people change culture change game joins classic book oz principle recent bestseller happen complete comprehensive series ever written workplace accountability based earlier book journey emerald city fully revised installment captures authors learned working hundreds thousands people using organizational culture strategic advantage',
#  "new edition best selling vocabulary practice title whether 're studying class english vocabulary use pre intermediate intermediate covers words phrases need level understand understood english new edition fully updated make book even relevant accessible",
#  "new postscript brain pickings creator maria popovarock star crowdfunding pioneer ted speaker amanda palmer knows asking performing living statue wedding dress wordlessly asked thousands passersby dollars became singer songwriter musician afraid ask audience support surfed crowd slept couches touring left record label strike asked fans support making album leading world 's successful music kickstarter even amanda celebrated attacked fearlessness asking help finds important things ask musician friend wife learns n't alone many people afraid ask help paralyzes lives relationships groundbreaking book explores barriers life lives around discovers emotional philosophical practical aspects art asking part manifesto part revelation story artist struggling new rules exchange twenty first century internet art asking inspire readers rethink ideas asking giving art love",
#  "updated reorganized fourth edition software testing craftsman 's approach applies strong mathematics content previous editions coherent treatment model based testing code based structural specification based functional testing techniques extended usual unit testing discussions full coverage less understood levels integration system testing fourth edition emphasizes technical inspections supplemented appendix full package documents required sample use case technical inspection introduces innovative approach merges event driven petri nets earlier editions swim lane concept unified modeling language uml permits model based testing four levels interaction among constituents system systems introduces model based development provides explanation conduct testing within model based development environments presents new section methods testing software agile programming environment explores test driven development reexamines pairs testing explains four contexts software testing thoroughly revised updated software testing craftsman ’ approach fourth edition sure become standard reference need stay date evolving technologies software testing carrying tradition previous editions continue serve valuable reference software testers developers engineers",
#  'transaction processing heart modern enterprise systems book explains depth transaction processing technology leveraged java platform provides comprehensive explanation underlying concepts transactions needed understand exploit technology correctly technical information delivered book corresponds directly latest revision java authors cover transactional aspects major j2ee components work practical consequences implementation choices addition text looks beyond java standards implementations provide broad interoperability across heterogeneous application environments finally book provides look emerging web services standards address next generation reliable information systems',
#  'based author ’ first hand experience expertise book offers proven framework global software engineering readers learn best practices managing variety software projects coordinating activities several locations across globe accounting cultural differences importantly readers learn engineer first rate software product efficiently possible fully leveraging global personnel resources global software takes unique approach works projects size examining critical topics executing seamless project across multiple locationsmitigating risks shoringdeveloping implementing processes global developmentestablishing practical outsourcing guidelinesfostering effective collaboration communication across continents culturethis book provides balanced framework planning global development covering topics managing people distributed sites managing project across locations delivers comprehensive business model beneficial anyone looking cost effective efficient way engineer good software products',
#  "advance praise carrots sticks n't work paul marciano provides wealth prescriptive advice absolutely makes sense actually open book chapter gain ideas immediate implementation beverly kaye coauthor love 'em lose 'em book hands anyone get work done people 's invaluable tool manager level john l rice vice president human resources tyco international carrots sticks n't work provides commonsense approach employee engagement dr marciano provides great real world insights data practical examples truly bring respect model life renee selman president catalina health resources respect model one dynamic engaging thought provoking employee engagement tools seen dr marciano 's work help provide meaningful long term benefits employees organization andy brantley president ceo college university professional association human resources book provides clear advice instruction engage team members inspire higher level productivity work satisfaction enjoyment already utilizing techniques finding immediate positive changes robert roth director accounting reporting colgate palmolive company title says carrots sticks n't work reward recognition programs costly inefficient primarily reward employees already highly engaged productive performers worse still programs actually decrease employee motivation make individual recognition rather overall success team goal yet many businesses turn measures first—unaware better alternative comes changing organizational culture carrots sticks ’ work work dr paul marciano 's acclaimed respect model gives specific low cost turnkey solutions action plans based seven key drivers employee engagement proven supported decades research practice—that empower assess troubleshoot resolve engagement issues workplace recognition acknowledgment employees ' contributions empowerment via tools resources information set employees succeed supportive feedback ongoing performance coaching mentoring partnering encourage foster collaborative working relationships expectations set clear challenging attainable performance goals consideration lets employees know cared trust employees ' abilities skills judgment carrots sticks n't work delivers proven resources techniques enabled trainers executives managers owners operations ranging branches united states government fortune 500 corporations twenty person outfits realize demonstrable gains employee productivity job satisfaction give little respect get effective organization reduced turnover absenteeism employees levels areengaged focused committed succeed team short get maximum roi organization 's powerful resource people",
#  'second edition book improves previous edition date current version 2 5 written around true patient encounter also additional v2 5 xml encoding example lab results hl7 health level 7 communication standard developed health care domain facilitates exchange messages health care information systems radiology laboratory patient scheduling billing etc book provides comprehensive guide hl7 version 2 x standard reader need experience hl7 standard book particular value anyone working imaging domain frequent references made ihe integrating health care enterprise standard defines profiles especially imaging domain book provide reader detailed explanation version 2 x messaging makes extensive use examples especially useful planning implement support need good understanding standard intended audience engineers system administrators interface engineers personnel anyone wants get thorough overview messaging protocol',
#  "summary software development metrics handbook anyone needs track guide software development delivery team level project managers team leads new development practices including agile methodologies like scrum redefined measurements meaningful conditions benefit practical book identifies key characteristics organizational structure process models development methods select appropriate metrics team describes uses mechanics common abuses number metrics useful steering monitoring process improvement insights techniques book based entirely field experience purchase print book includes free ebook pdf kindle epub formats manning publications book driving car less likely speed run gas suffer engine failure measurements car reports condition development teams less likely fail measuring parameters matter success projects book shows software development metrics teaches gather analyze effectively use metrics define organizational structure process models development methods insights examples book based entirely field experience 'll learn practical techniques like building tools track key metrics developing data based early warning systems along way 'll learn metrics align different development practices including traditional adaptive methods formal experience developing applying metrics assumed 's insideidentify valuable metrics team processdifferentiate improvement change learn interpret apply data gathercommon pitfalls anti patternsabout authordave nicolette organizational transformation consultant team coach trainer dave active agile lean software communities table contentsmaking metrics usefulmetrics steeringmetrics improvementputting metrics workplanning predictabilityreporting outward upward",
#  "drawing dale carnegie 's years experience business trainer book show overcome natural fear public speaking become successful speaker even learn enjoy invaluable advice includes ways develop poise gain self confidence improve memory make meaning clear begin end presentation effectively interest charm audience improve diction win argument without making enemies",
# ...
#  'book story author built unit diamond andin international use principles collected intellectual ancient buddhism nothing functioning students world many millions dollars year decisions policies author units author vice chairman failure played rules find book principle divide ba nguyen first rule business succeed ie must generate cash popular belief us west success make money way mistake anyone trying spiritual life buddhism though money bad fact person money good deeds world main problem make money somehow understand money arising money continues come maintained healthy attitude money switch khong nguyen second enjoy money ie need learn keep spirit body healthy make money operating assets generated make us tired physically mentally enjoy property devastating health business business dissipated ie real purpose doanh nguyen third principle look back get business career finally honestly years business sense tom business purposes ancient tibetan wisdom indeed human endeavor make rich achieve prosperity outside inside enjoy prosperity maintain high level physical health mental throughout life must find ways make prosperity meaningful broader perspective',
#  'need work harder even may need comply order step step guidance bestseller getting things done difficulty however time must better control part work complete innovative able cover better focus things care creative new structures job flexibility comfort simply prepare advance next step keen desire build better life job attractive book make definitely',
#  "allen 's message briefly please reorganize liberate mind focus truly deserves achieve highest productivity without stress book everything done difficult coach veteran management consultant david allen shares effective method help well tens thousands others training stress reduction find comfort lives everything done difficult know apply principle make transfer suspension skip free memory reassess goals maintain ability refocus circumstances change plan seek remove project hanging overcoming feeling confused anxious unable control feeling satisfied really",
#  "continuing exploration organization complexity science design new edition herbert simon 's classic work artificial intelligence adds chapter sorts current themes tools chaos adaptive systems genetic algorithms analyzing complexity complex systems updates throughout book well take account important advances cognitive psychology science design confirming extending book 's basic thesis physical symbol system necessary sufficient means intelligent action chapter economic reality also revised reflect change emphasis simon 's thinking respective roles organizations markets economic systems",
#  'book fast paced guide help clear exam confidence learn design develop deploy cloud based solutions using aws enhance aws skills practice questions mock tests book book professionals developers looking clear aws certified developer associate 2017 exam developers looking develop manage applications aws platform also find book useful prior aws experience needed learn create manage users groups permissions using aws identity access management services create secured virtual private cloud vpc public private subnets network access control security groups get started elastic compute cloud ec2 launching first ec2 instance working handle application traffic elastic load balancing elb monitor aws resources cloudwatch work aws storage services simple storage service s3 glacier cloudfront get acquainted aws dynamodb nosql database service coordinate work across distributed application components using simple workflow service swf detail aws certified developer associate guide starts quick introduction aws prerequisites get started book gives fair understanding core aws services basic architecture next book describe getting familiar identity access management iam along virtual private cloud vpc moving ahead learn elastic compute cloud ec2 handling application traffic elastic load balancing elb going ahead talk monitoring cloudwatch simple storage service s3 glacier cloudfront along aws storage options next take aws dynamodb nosql database service amazon simple queue service sqs cloudformation overview finally book covers understanding elastic beanstalk overview aws lambda end book cover enough topics tips tricks along mock tests able pass aws certified developer associate exam develop well manage applications aws platform style approach step step guide includes exercises mock tests clear aws certification exam become successful aws developer table contents overview aws certified developer associate certification introduction cloud computing aws getting familiar identity access management virtual private cloud getting started elastic compute cloud handling application traffic elastic load balancing monitoring cloudwatch simple storage service glacier cloudfront aws storage options aws relation database services aws dynamodb nosql database service amazon simple queue service simple notification service simple workflow service aws cloudformation elastic beanstalk overview aws lambda mock tests',
#  'thorough coverage improvements changes sharepoint 2010 sharepoint 2010 boasts variety incredible new features challenge even experienced administrator upgrading sharepoint 2007 written team sharepoint experts book places takes aim showing make new features work right offering depth look sharepoint 2010 authors focus sharepoint functionality changed earliest version newest provide detailed coverage new features capabilities presents depth coverage new features functions sharepoint 2010 demonstrates installation configuration upgrading existing sharepoint 2007 servers discusses architecture capacity planning securing managing site content integrating office clients details protocol handling monitoring creating backups executing disaster recovery addresses shared service applications navigation governance business intelligence reporting services professional sharepoint 2010 presents solid understanding functionality sharepoint 2010 provides allow see',
#  "get jump start building applications bootstrap today originally developed twitter bootstrap framework making arduous process crafting fully responsive web designs breeze discover bootstrap fast becoming favorite tool top web designers one weekend hands tutorial 'll learn integrate bootstrap projectsunderstand basic bootstrap templatework bootstrap 's gridcustomize bootstrap work project",
#  'past 10 years distributed systems become fine grained large multi million line long monolithic applications seeing benefits smaller self contained services rather heavy weight hard change service oriented architectures seeing systems consisting collaborating microservices easier change deploy required retire organizations right position take advantage yielding significant benefits book takes holistic view things need cognizant order pull covers enough understanding technology architecture operations organization show move towards finer grained systems',
#  'choose several data access frameworks building java enterprise applications work relational databases big data hands introduction shows spring data makes relatively easy build applications across wide range new data access technologies nosql hadoop several sample projects ’ learn spring data provides consistent programming model retains nosql specific features capabilities helps develop hadoop applications across wide range use cases data analysis event stream processing workflow ’ also discover features spring data adds spring ’ existing jpa jdbc support writing rdbms based data access layers learn spring ’ template helper classes simplify use database specific functionality explore spring data ’ repository abstraction advanced query functionality use spring data redis key value store hbase column family mongodb document database neo4j graph database discover gemfire distributed data grid solution export spring data jpa managed entities web restful web services simplify development hbase applications using lightweight object mapping framework build example big data pipelines spring batch spring integration',
#  'david meerman scotts marketing bible become modern day business classic book every ambitious forward thinking progressive marketer publicist front shelf business communication changed recent years creative ad copy longer enough new rules marketing pr brought thousands marketers speed changing requirements promoting products services new digital age one kind pioneering guide offering step step action plan harnessing power internet communicate buyers directly raise online visibility increase sales getting right message right people right time fraction cost big budget advertising campaign new updated edition includes new introduction discussing recent changes world marketing pra brand new chapter mobile marketingan additional chapter real time marketing prupdated information measure success campaignsa range new toolsfresh case studies',
#  "microsoft 's windows presentation foundation wpf provides foundation building applications high quality user experiences windows operating system blends application user interface documents media content exploiting full power computer 's operating system functionality extends support tablet pcs forms input device provides modern imaging printing pipeline accessibility ui automation infrastructure data driven user interfaces visualization integration points weaving application experience windows shell book shows wpf really works provides nonsense practical advice need order build high quality wpf applications quickly easily giving firm foundation goes explore advance aspects wpf relate others elements net 4 0 platform associated technologies silverlight",
#  "someone uses jquery regular basis surprising discover much library ’ using book indispensable anyone serious using jquery non trivial applications raffaele cecco longtime developer video games including cybernoid exolon stormlordjquery write less javascript library powerful features ease use made popular client side javascript framework web ideal javascript developers skill levels book jquery 's trusty companion definitive read less learn guide library jquery pocket reference explains everything need know jquery completely comprehensively 'll learn select manipulate document elementsalter document structurehandle trigger eventscreate visual effects animationsscript http ajax utilitiesuse jquery 's selectors selection methods utilities plugins morethe 25 page quick reference summarizes library listing jquery methods functions signatures descriptions",
#  'would like use consistent visual notation drawing integration solutions look inside front cover want harness power asynchronous systems without getting caught pitfalls see thinking asynchronously introduction want know style application integration best purposes see chapter 2 integration styles want learn techniques processing messages concurrently see chapter 10 competing consumers message dispatcher want learn track asynchronous messages flow across distributed systems see chapter 11 message history message store want understand system designed using integration patterns implemented using java web services net message queuing tibco based publish subscribe architecture see chapter 9 interlude composed messaging utilizing years practical experience seasoned experts gregor hohpe bobby woolf show asynchronous messaging proven best strategy enterprise integration success however building deploying messaging solutions presents number problems developers enterprise integration patterns provides invaluable catalog sixty five patterns real world solutions demonstrate formidable messaging help design effective messaging solutions enterprise authors also include examples covering variety different integration technologies jms msmq tibco activeenterprise microsoft biztalk soap xsl case study describing bond trading system illustrates patterns practice book offers look emerging standards well insights future enterprise integration might hold book provides consistent vocabulary visual notation framework describe large scale integration solutions across many technologies also explores detail advantages limitations asynchronous messaging architectures authors present practical advice designing code connects application messaging system provide extensive information help determine send message route proper destination monitor health messaging system want know manage monitor maintain messaging system use get book 0321200683b09122003',
#  "want sound like native speaker english need key phrases conversational tools native speakers use get message across collins speaking help become confident fluent speaker english choosing right words pronunciation tone learn start conversations keep conversations going deal difficult situations includes practice starting conversations interrupting making suggestions giving receiving compliments asking giving opinions saying politely collins speaking part new english life series uses authentic material collins corpus world 's largest database english language suitable self study classroom use help towards cambridge fce preparation suitable intermediate learners english cef level b1+",
#  'compiling net common language runtime gives software engineers critical information creating net compilers implementing net programming languages renowned compiler expert john gough goes ¿under hood¿ clr illuminating key concepts covering every facet architecture behavior gough presents extensive examples many drawn c gough¿s open source gardens point component pascal compiler',
#  '180 grammar topics organized 2 page sections explains grammar topic used avoid mistakes includes tip help students sound natural covers topics students need know cambridge esol exams fce cae cpe',
#  "visionary ceo zappos explains emphasis corporate culture lead unprecedented success pay new employees 2000 quit make customer service entire company department focus company culture 1 priority apply research science happiness running business help employees grow personally professionally seek change world oh make money sound crazy 's standard operating procedure zappos com online retailer 's 1 billion gross merchandise sales every year 1999 tony hsieh pronounced shay sold linkexchange company co founded microsoft 265 million joined zappos adviser investor eventually became ceo 2009 zappos listed one fortune magazine 's top 25 companies work acquired amazon later year deal valued 1 2 billion day closing first book tony shares different business lessons learned life lemonade stand pizza business linkexchange zappos ultimately shows using happiness framework produce profits passion purpose business life edited author",
#  "build high performing teams evidence based framework delivers results committed teams three steps inspiring passion performance based deceptively simple philosophy set direction try stay track make adjustments necessary easy hardly especially typical workday time crunched stressful deadline driven drawing research done wharton school business authors reveal deliver results tough conditions tested refined wharton 's executive development program committed teams help gain buy shared objectives assign roles right people establish norms effective collaboration whether team aims execute strategy produce breakthrough innovations collaborate across global boundaries launch new venture guide offers pragmatic advice need engaging stories illustrative examples business entertainment sports arts bring three step process life game changing book provides tools aligning every member team behind motivating visionmaking team meetings efficient productiveclosing gap stated goals actual behaviors want competitive demanding fast paced work environment need rely high performing team committed teams indispensable resource creating one"]

# %% [markdown]
# ### Stemming
# Stemming is the process of converting a word to its basic form. The idea is that these morphological variants only use for grammatically purpose instead of having any extra meaning.
#
# For example:
#
#     looks -> look
#
#     looking -> look
#
#     looked -> look

# %%
ps = PorterStemmer()

# %%
sentence = "Programers program with programing languages"
words = word_tokenize(sentence) 
for w in words: 
    print(w, " : ", ps.stem(w))
# Out:
# Programers  :  program
# program  :  program
# with  :  with
# programing  :  program
# languages  :  languag

# %%
for idx, description in enumerate(corpus):
    tokenized_description = word_tokenize(description)
    new_description = [ps.stem(w) for w in tokenized_description]
    corpus[idx] = " ".join(new_description)

# %%
corpus
# Out:
# ['compani size find urgent new prioriti keep employe book take reader critic idea employe retent use call three rs employe retent respect recognit reward basi program design keep peopl around',
#  "written softwar develop softwar develop book uniqu collect latest softwar develop method author includ ood uml design pattern agil xp method detail descript complet softwar design reusabl program c++ java use practic problem solv approach show develop object orient application—from earli stage analysi low level design implement walk reader design 's thought — show error blind alley creativ insight occur throughout softwar design process book cover static dynam principl class design complex manag principl packag design analysi design pattern paradigm cross explain principl ood one one demonstr numer exampl complet work design case studi cover trap pitfal work around applic c++ ood show agil method use discuss method design develop big softwar detail featur three chapter depth singl case studi build secur system softwar engin programm analyst want understand design object orient softwar state art method",
#  "text must interest enough student want read languag otherwis expect student want read english author ' golden rule choos text topic everi level american english file ensur get materi learner enjoy read want talk text 'could live without money ' realli help gener opinion discuss creat desir commun creat desir american english file help develop learner ' commun skill one way strong focu pronunci research show poor pronunci major contributor breakdown commun jennif jenkin phonolog english intern languag american english file integr pronunci everi lesson 'littl often ' approach 's uniqu english file sound chart put pictur sound phonet alphabet learner find easier rememb sound ultim improv pronunci",
#  "tabl content section 1 1 career 2 get start bang n't everyon els 3 think futur goal 4 peopl skill need think 5 hack interview 6 employ option enumer choic 7 kind softwar develop 8 compani equal 9 climb corpor ladder 10 profession 11 freedom quit job 12 freelanc go 13 creat first product 14 want start startup 15 work remot surviv strategi 16 fake till make 17 resum bore let 's fix 18 n't get religi technolog section 2 market 19 market basic code monkey 20 build brand get notic 21 creat wildli success blog 22 primari goal add valu other 23 use social network 24 speak present train speak geek 25 write book articl attract follow 26 n't afraid look like idiot section 3 learn 27 learn learn teach 28 10 step process 29 step 1 6 30 step 7 10 repeat 31 look mentor find yoda 32 take apprentic yoda 33 teach learn want teach must",
#  'nassim nichola taleb bestsel author black swan one foremost thinker time reveal thrive uncertain world human bone get stronger subject stress tension rumor riot intensifi someon tri repress mani thing life benefit stress disord volatil turmoil taleb identifi call “ antifragil ” categori thing gain chao need order surviv flourish black swan taleb show us highli improb unpredict event underli almost everyth world antifragil taleb stand uncertainti head make desir even necessari propos thing built antifragil manner antifragil beyond resili robust resili resist shock stay antifragil get better better furthermor antifragil immun predict error protect advers event citi state better nation state debt bad call “ effici ” effici govern respons social polici protect strong hurt weak write resign letter even start job sink titan save live book span innov trial error life decis polit urban plan war person financ econom system medicin throughout addit street wisdom fat toni brooklyn voic recip ancient wisdom roman greek semit mediev sourc loud clear antifragil blueprint live black swan world erudit witti iconoclast taleb ’ messag revolutionari antifragil antifragil make prais antifragil “ ambiti thought provok highli entertain ” —the economist “ bold book explain embrac uncertainti random error may chang live ” —newsweek “ revelatori taleb pull reader along logic socrat ” —chicago tribun “ startl richli cram insight stori fine phrase intrigu asid read ” —matt ridley wall street journal “ trenchant persuas taleb ’ insati polymath curios know bound finish book feel braver uplift ” —new statesman “ antifragil ’ sound econom polit doctrin ’ also key good life ” —fortun “ thought provok brilliant ” —lo angel timesfrom hardcov edit',
#  'extrem program ideal mani softwar shop would love reach constant pressur produc softwar quickli actual implement agil softwar process allow compani implement extrem program quickli immedi begin produc softwar increment littl 30 day implement extrem program easier said done process time consum actual slow current softwar project process book show reader use scrum agil softwar develop process quickli seamlessli implement xp shop still produc actual softwar use scrum agil process virtual elimin downtim xp implement',
#  "edit provid comprehens approach invest fundament need success cfp exam advanc topic reader learn make solid real invest decis applic updat 'financi advisor 's invest case ' end chapter latest internet assign",
#  "cultur leadership abil chang determin organiz perform 75 organiz chang program fail conceptu organ wide command control like 's chang consult marcella bremer develop pragmat approach organiz cultur chang leadership start point valid organiz cultur assess instrument base compet valu framework professor kim cameron robert quinn next bremer show engag peopl ocai workshop chang circl peer group 10 cowork develop chang plan team also person focus specif behavior chang circl 10 use mechan copi coach correct within group help organ member implement chang develop behavior make differ book pragmat user ’ guid organiz cultur chang learn best practic chang consult unleash organ",
#  "busi plu three level integr skill busi english cours a1 fals beginn b1 pre intermedi level level student 's book 10 unit design easi enjoy teach unit featur integr skill languag practic unit also includ cultur awar section connect learner region beyond addit toeic style practic section allow student ' progress measur",
#  'textbook adopt uniqu approach help develop cs student learn hadoop mapreduc program fast rather fill disjoint piecem code snippet show hadoop mapreduc program featur one time design place total hadoop mapreduc program learn process common applic context mine custom spend pattern ensconc larg volum credit card transact record data precis end end procedur given help set hadoop mapreduc develop environ quickli eclips maven mac os x step step procedur also given set four node linux cluster minimum run mapreduc program local mode mac os x machin also fulli distribut mode real cluster fact mapreduc program present book test verifi local mode linux cluster textbook mainli focus teach hadoop mapreduc program scientif object quantit approach rather heavili reli subject verbos sometim even pompou textual descript spars code snippet textbook use hadoop java api hadoop configur paramet complet mapreduc program execut log output demonstr hadoop mapreduc framework work write mapreduc program specif text cover follow subject introduct hadoop set linux hadoop cluster hadoop distribut filesystem mapreduc job orchestr workflow basic mapreduc program advanc mapreduc program hadoop stream hadoop administrationno matter role play team text help gain truli applic hadoop skill effect effici manner book also use supplementari textbook distribut comput hadoop cours offer upper divis colleg cs student',
#  "highli success secur book return new edit complet updatedweb applic front door organ expos attack may disclos person inform execut fraudul transact compromis ordinari user practic book complet updat revis discuss latest step step techniqu attack defend rang ever evolv web applic 'll explor variou new technolog employ web applic appear sinc first edit review new attack techniqu develop particularli relat client side reveal overcom new technolog techniqu aim defend web applic attack appear sinc previou editiondiscuss new remot framework html5 cross domain integr techniqu ui redress framebust http paramet pollut hybrid file attack morefeatur companion web site host author allow reader tri attack describ give answer question pose end chapter provid summar methodolog checklist tasksfocus area web applic secur thing chang recent year book current resourc critic topic discov exploit prevent web applic secur flaw",
#  "practic guid softwar develop differ softwar architectur book 's teach risk driven architect need meticul design risk small excus sloppi design risk threaten success book describ way enough architectur avoid one size fit process tar pit advic tune design effort base risk face democrat architectur book seek make architectur relev softwar develop develop need understand use constraint guiderail ensur desir outcom seemingli small chang affect system 's properti cultiv declar knowledg differ abl hit ball know abl hit psychologist refer procedur knowledg versu declar knowledg book make awar provid name concept emphas engin book focus technic part softwar develop develop ensur system work job titl process show build model analyz architectur make principl design tradeoff describ techniqu softwar design use reason medium larg size problem point learn special techniqu detail provid practic advic softwar design decis influenc architectur vice versa approach book embrac drill pop behavior describ model variou level abstract architectur data structur design",
#  'pro android 2 show build real world fun mobil applic use googl ’ latest android softwar develop kit new edit updat android 2 cover everyth fundament build applic embed devic advanc concept custom 3d compon opengl touchscreen includ gestur android develop guid simpli discuss topic pro android 2 offer combin expert insight real sampl applic work discov design architectur android sdk practic exampl build mobil applic use android sdk explor use android api includ media wi fi learn android 2 ’ integr local web search handwrit gestur ui googl translat text speech featur pro android 2 dive deep provid knowledg techniqu need build mobil applic rang game googl app includ add on googl doc ’ abl extend run new googl chrome api g1 g2 next gener googl phone android enabl devic ’ learn use android build java base mobil applic googl phone touch screen keyboard thank cupcak ’ inclus android 1 5 design architect use googl ’ latest android sdk use android sdk write mobil applic embed devic creat 3d graphic opengl custom compon build multimedia game app use android ’ media api opengl use android ’ locat base servic network wi fi api secur creat allow integr local web search build handwrit gestur ui incorpor googl translat android applic book book profession softwar engin programm look move idea applic mobil space android assum reader passabl understand java includ abl write class handl basic inherit structur book also target hobbyist tabl content introduc android comput platform get feet wet use resourc content provid intent build user interfac use control work menu dialog unveil 2d anim explor secur locat base servic build consum servic use media framework telephoni api program 3d graphic opengl manag organ prefer explor live folder home screen widget android search explor text speech translat api touchscreen titanium mobil webkit base approach android develop work android market outlook resourc',
#  "five year 100 000 copi first publish 's hard imagin anyon work web design n't read steve krug 's instant classic web usabl peopl still discov everi day second edit steve add three new chapter style origin wri entertain yet load insight practic advic novic veteran alik n't surpris complet chang way think web design three new chapter usabl common courtesi peopl realli leav web site web access css make site usabl access help boss want surviv execut design whim thought usabl enemi design read first edit book n't make think show put posit person use site read coupl hour put idea work past five year say done improv abil web design book second edit steve krug add essenti ammunit whose boss client stakehold market manag insist wrong thing design write program manag web site must read book jeffrey zeldman author design web standard",
#  'global outsourc defin seamless integr onsit onshor nearshor offshor deliveri team rapidli becom execut deliveri strategi choic busi process project corpor today book goe beyond theori explain step step methodolog manag follow execut global outsourc strategi design implement manual global outsourc discuss detail task involv plan sourc execut phase everi project',
#  "alic 's adventur wonderland 1865 novel written english author charl lutwidg dodgson better known pseudonym lewi carrol tell stori girl name alic fall rabbit hole fantasi world popul peculiar anthropomorph creatur 1865 dodgson 's tale publish alic 's adventur wonderland lewi carrol illustr john tenniel first print run 2 000 destroy tenniel object print qualiti new edit releas decemb year carri 1866 date quickli print reproduct edit",
#  'complex world product easi use win favor consum first book topic simplic aim specif interact design show drill simplifi user experi design digit tool applic begin explain simplic attract explor law simplic present proven strategi achiev simplic remov hide organ displac becom guidelin design learn simplic see exampl case studi result speak',
#  "hibern make java base data persist incred easi perform popular resourc make hibern technolog darn imposs learn well learn hibern n't hard anymor copi hibern made easi side cameron mckenzi 's hibern made easi final bring light idea technolog fun easi use also fun easi learn build upon simpl straight forward exampl make even difficult topic easi understand book explor key concept absolut must know order start effect leverag hibern framework discard old xml base hbm map file hibern made easi show simplifi design leverag hibern jpa annot togeth make applic manag maintain importantli faster easier develop fundament creat retriev updat delet oper map complex inherit hierarchi hibern made easi explain use friendli convers style read less like technic book like inform convers hibern expert exampl book incred easi follow reproduc code error book guarante concept book help learn empow solv even daunt program challeng manag transact http base request respons cycl implement highli advanc data access object dao java 5 gener book teach realli need know java base persist hibern want learn hibern want learn hibern quickli want explain manner easi follow understand realli choic get copi cameron mckenzi 's hibern made easi today inform check hiberbook com",
#  "asp net 4 princip standard creat dynam web page window platform pro asp net 4 c 2010 rais bar high qualiti practic advic learn deploy microsoft 's dynam web solut edit updat everyth need master version 4 asp net includ coverag asp net mvc asp net ajax 4 asp net dynam data silverlight 3 season net profession matthew macdonald mario szpuszta explain get groundbreak technolog cover asp net 4 whole illustr newer featur function carri previou version asp book give knowledg need code real asp net 4 applic best possibl style",
#  'matter much experi javascript odd ’ fulli understand languag part ’ know js seri compact guid focus new featur avail ecmascript 6 es6 latest version standard upon javascript built like book seri ’ know js es6 beyond dive trickier part languag mani javascript programm either avoid know noth arm knowledg achiev true javascript masteri book learn new es6 syntax eas pain point common program idiomsorgan code iter gener modul classesexpress async flow control promis combin generatorsus collect work effici data structur waysleverag new api helper includ array object math number stringextend program ’ capabl meta programmingpreview featur like come js beyond es6',
#  "best practic guid manag infrastructur fulli updat nbsp system manag minut guid maintain stabl respons product environ top system manag expert rich schiesser illumin theoret practic aspect system manag use method exampl drawn decad experi lead consult world 's complex enterpris organ nbsp thoroughli updat edit cover everi system manag disciplinenbsp element success peopl process technolog schiesser show appli best practic system manag throughout infrastructur environ mainfram data center web enabl system client server mid rang platform wireless voip network nbsp nbsp schiesser systemat address today 's crucial issu well emerg trend transform system manag 'll find entir new chapter use infrastructur librari itil effect plu new coverag rang manag outsourc function effici deliv ultra speed internet connect edit includ real life exampl throughout new interact problem design give profession even deeper insight coverag includ nbsp nbsp implement bullet proof process area rang chang manag product accept capac plan storag nbsp optim peopl compon servic deliveri custom servic execut support nbsp use technolog manag system effici effect nbsp systemat manag perform avail busi continu nbsp reduc cost complex facil manag nbsp take strateg approach secur nbsp nbsp rich schiesser found own rw enterpris inc consult special design implement world class infrastructur client list includ weather channel amazon com directv led major infrastructur organ hugh aircraft citi lo angel twentieth centuri fox nearli ten year manag primari data center northrop grumman one world 's advanc comput facil former univers phoenix faculti member taught manag ucla california state univers lo angel csula nbsp informit com ph nbsp nbsp",
#  'learn interview skill need interview success import proper interview techniqu underst recruit impact revenu strateg goal competit advantag organiz success success area paramount healthi success busi role interview extrem import must know job well interview success allow quickli learn find inform need know candid make good hire decis ’ learn review résumé prepar interview legal ask candid behavior interview techniqu much',
#  'primer hl7 version 3 healthcar interoper standard',
#  'cda book provid clear easi use guidanc implement standard numer exampl cover mani nuanc standard reader learn implement healthcar use cda standard speak languag standard understand idiom',
#  "ca n't get realli want desir readi will partner help exploit drive busi instead get endless rule regul mention process project technolog deliv littl late much 's frustrat build relationship put firmli control produc busi result need 8 thing hate susan cramm provid answer start understand differ oper manag background person pressur incent cramm explain differ prevent oper manag commun cite case studi stori author present practic strategi overcom difficulti includ see thing partner ' perspect develop singl version 'truth ' assum account 've done manag firm 's financi human resourc brutal honest provoc fill sound advic book reveal key solv problem decidedli un 's deeper understand human behavior includ appli leadership skill world",
#  'design pattern mapreduc framework scatter among variou research paper blog book handi guid bring togeth uniqu collect valuabl mapreduc pattern save time effort regardless domain languag develop framework ’ use pattern explain context pitfal caveat clearli identifi help avoid common design mistak model big data architectur book also provid complet overview mapreduc explain origin implement design pattern import code exampl written hadoop summar pattern get top level view summar group data filter pattern view data subset record gener one user data organ pattern reorgan data work system make mapreduc analysi easier join pattern analyz differ dataset togeth discov interest relationship metapattern piec togeth sever pattern solv multi stage problem perform sever analyt job input output pattern custom way use hadoop load store data clear exposit mapreduc program common data process patterns—thi book indespens anyon use hadoop tom white author hadoop definit guid',
#  "googl execut chairman ex ceo eric schmidt former svp product jonathan rosenberg came googl decad ago proven technolog execut time compani alreadi well known thing differ reflect visionari frequent contrarian principl founder larri page sergey brin eric jonathan go succeed realiz would relearn everyth thought knew manag busi today googl global icon regularli push boundari innov varieti field googl work entertain page turn primer contain lesson eric jonathan learn help build compani author explain technolog shift balanc power compani consum way succeed ever chang landscap creat superior product attract new breed multifacet employe eric jonathan dub smart creativ cover topic includ corpor cultur strategi talent decis make commun innov deal disrupt author illustr manag maxim consensu requir dissens exil knave fight diva think 10x 10 numer insid anecdot googl 's histori mani share first time era everyth speed best way busi succeed attract smart creativ peopl give environ thrive scale googl work explain",
#  "salesforc com grow start rent apart world 's fastest grow softwar compani less decad first time marc benioff visionari founder chairman ceo salesforc com tell team creat use new busi technolog philanthrop model tailor time extraordinari chang show salesforc com surviv dotcom implos 2001 went defin leader cloud comput revolut spark 46 billion dollar industri benioff 's stori help busi leader entrepreneur stand innov better grow faster econom climat behind cloud benioff share strategi inspir employe turn custom evangelist leverag ecosystem partner allow innov flourish",
#  "employe compani 's number one asset hire best offer manag hr personnel proven practic approach recruit select right peopl job 400 question use interview candid obtain pertin inform 'll arm tool need ensur inde hire best complet revis updat updat includ new section electron recruit revis resourc section inform law guidelin influenc hire practic hire best allow determin candid job also manag effect thrive new posit",
#  "summarysolr action comprehens guid implement scalabl search use apach solr clearli written book walk well document exampl rang basic keyword search scale system billion document queri give deep understand implement core solr capabl bookwheth 're handl big small data manag document build websit import abl quickli search content discov mean apach solr tool readi deploy lucen base open sourc full text search engin solr scale across mani server enabl real time queri data analyt across billion document solr action teach implement scalabl search use apach solr easi read guid balanc conceptu discuss practic exampl show implement solr 's core capabl 'll master topic like text analysi facet search hit highlight result group queri suggest multilingu search advanc geospati data oper relev tune book assum basic knowledg java standard databas technolog prior knowledg solr lucen requir purchas print book includ free ebook pdf kindl epub format man public 's insidehow scale solr big datarich real world examplessolr nosql data storeadvanc multilingu data relev trickscoverag version solr 4 7about authorstrey grainger director engin careerbuild timothi potter senior member engin team lucidwork author work scalabl reliabl solr well recommend engin big data analyt technolog tabl contentspart 1 meet solrintroduct solrget know solr key solr concept configur solr index text analysi part 2 core solr capabilitiesperform queri handl resultsfacet searchhit highlightingqueri suggestionsresult group field collapsingtak solr productionpart 3 take solr next levelsolrcloudmultilingu searchcomplex queri operationsmast relev",
#  "winner 2010 nation staff develop council 's staff develop book year awardbronz medal award winner foreword review 2009 book year awardbuild profession learn commun worktm guid first year address real world critic question aris school begin work becom profession learn commun administr teacher take promis plc turn realiti school leader transform theori collabor highli effect nut bolt practic book set context one year life plc chronicl effort build princip steve teacher build true plc central middl school focus success challeng inher process chapter includ four element open stori highlight import event growth learn commun lesson front line spotlight success decis common mistak made charact open stori relev theori research section introduc theori expert connect work plc provid reader approach framework understand languag describ complex yet predict chang inevit school restructur plc recommend section offer collect suggest draw work chang build lesson build profession learn commun work drawn author experi work teacher build administr consult coach elementari middl high school level emphas power collabor happen anywher requir hard work purpos step deep understand plc model tool book test time real teacher team",
#  'one semest undergradu graduat level cours organiz behavior titl pearson global edit editori team pearson work close educ around world includ content especi relev student outsid unit state concis fundament student ultim flexibl instructor bestsel brief altern ob cours cover key concept need understand predict respond behavior peopl real world organ text also includ cut edg topic streamlin pedagogi allow maximum flexibl design shape cours eleventh edit contain expand updat coverag intern issu well new section manag inform safeti emot work risk avers self determin theori manag inform downsiz accompani mymanagementlab see hand air hear roar discuss rock star classroom mymanagementlab make easier rock classroom help hold student account class prepar get student engag materi array relev teach media resourc visit mymanagementlab com inform',
#  'book take depth look deploy hyper v second gener popular hyper v boast technic advanc creat even dynam system ever uniqu resourc serv authorit guid deploy window server 2008 r2 hyper v comprehens step step instruct demonstr design hyper v deploy build hyper v host environ design manag system system center virtual machin manag 2008 r2 featur real world exampl show design hyper v deploy build hyper v host environ design manag system walk incorpor system center oper manag 2008 r2 system center data protect manag 2010 system center essenti 2010 offer authorit coverag hyper v secur busi continu array vm role includ domain control exchang server sql server system center depth guid ultim resourc system administr engin architect consult deploy hyper v',
#  'electron payment econom backbon e commerc transact book cover major subject relat e payment exampl public key infrastructur smart card payment agent digit cash set protocol micro payment first part cover infrastructur secur e payment internet wherea second part varieti e payment method system describ edit volum offer well written sound technic overview state art e payment e busi develop graduat student consult also ideal suit class train cours e commerc e payment',
#  "architect scrum master team leader project manag find leadership done right tough job book deal hard part tool peopl manifesto drive book us team leader goal way measur work overal growth skill self organ self mainten member team team whole end • accept team 's need us chang continu base skill handl current realiti work embrac continu chang leadership style one style fit leadership approach • believ challeng team alway get better • creat slack time team learn challeng • embrac take risk team stay safe • embrac fear discomfort learn new skill keep peopl within comfort zone • embrac experiment constant practic maintain statu quo • peopl • tool • process • environ • believ core practic lead peopl wield machin • embrac spend time team meet • embrac treat softwar problem peopl problem • learn peopl skill commun techniqu note second part book allow peek mind best leader consult manag give advic new team leader hear johanna rothman kevlin henney dan north uncl bob martin mani other one thing would like teach ever becom team leader scrum master project manag architect",
#  'offici curriculum appl yosemit 101 os x support essenti 10 10 cours prepar appl certifi support profession acsp 10 10 certification–a well top notch primer anyon need support troubleshoot optim os x yosemit guid provid comprehens coverag yosemit part appl pro train series–th appl certifi book market design support technician help desk specialist ardent mac user guid take deep insid yosemit oper system reader find depth step step instruct everyth instal configur yosemit manag network system administr whether run comput lab depart ’ learn set user configur system prefer manag secur permiss use diagnost repair tool troubleshoot peripher devic more–al way prepar industri standard acsp certif cover updat system util new featur os x yosemit featur authorit explan underli technolog troubleshoot system administr much focus lesson take step step practic real world task lesson file bonu materi avail download–includ lesson review question summar ’ learn prepar appl certif exam',
#  "simpl power market strategi everi busi afford implementther 's never better time market entrepreneur right thank internet new world free inexpens tactic help get word prospect busi limit market budget free market deliv 100 idea help small busi owner market gener new revenu littl market budget internet base creativ offlin idea 'll discov way turn top custom unpaid sale forc get competitor help promot new product grow loyal audienc devour content spread word product servic caus person use simpl video promot power toolshold ebay auction public purpos author jim cockrum made 30 000 earn ton free public one auction find perfect onlin partner take next level quickli grow success busi without let market budget tell jim cockrum proven power market strategi cheapest",
#  'matter much experi javascript odd ’ fulli understand languag part ’ know js seri concis yet depth guid focus new asynchron featur perform techniques—includ promis gener web workers—that let creat sophist singl page web applic escap callback hell process like book seri ’ know js async perform dive trickier part languag mani javascript programm simpli avoid arm knowledg becom true javascript master book explor old new javascript method handl asynchron programmingunderstand callback let third parti control program ’ executionaddress invers control issu javascript promisesus gener express async flow sequenti synchron look fashiontackl program level perform web worker simd asm jslearn valuabl resourc techniqu benchmark tune express statement',
#  "comprehens process defin softwar architectur work good softwar architectur foundat success softwar system effect architect requir clear understand organiz role artifact activ perform optim sequenc perform activ process softwar architect peter eel peter cripp provid guidanc challeng cover aspect architect softwar system introduc best practic techniqu appli everi environ whether base java ee microsoft net technolog eel cripp first illumin concept relat softwar architectur includ architectur document reusabl asset next present access task focus guid tour typic project focus architect 's role common issu illumin address throughout final conclud set best practic appli today 's complex system come away book understand role architect typic softwar develop project document softwar architectur satisfi need differ stakehold applic reusabl asset process architect role architect respect requir definit deriv architectur base set requir relev architect creat complex system process softwar architect indispens resourc everi work aspir softwar architect everi project manag softwar profession need understand architectur influenc work",
#  'first volum qualiti softwar manag seri gerald weinberg tackl first requir develop qualiti softwar learn think correctli problem solut qualiti guidelin manag introduc stimul kind think need',
#  'fulli revis updat instal bestsel author oz principl seri two time new york time bestsel author roger connor tom smith show leader achiev record break result quickli effect shape organiz cultur capit greatest asset peopl chang cultur chang game join classic book oz principl recent bestsel happen complet comprehens seri ever written workplac account base earlier book journey emerald citi fulli revis instal captur author learn work hundr thousand peopl use organiz cultur strateg advantag',
#  "new edit best sell vocabulari practic titl whether 're studi class english vocabulari use pre intermedi intermedi cover word phrase need level understand understood english new edit fulli updat make book even relev access",
#  "new postscript brain pick creator maria popovarock star crowdfund pioneer ted speaker amanda palmer know ask perform live statu wed dress wordlessli ask thousand passersbi dollar becam singer songwrit musician afraid ask audienc support surf crowd slept couch tour left record label strike ask fan support make album lead world 's success music kickstart even amanda celebr attack fearless ask help find import thing ask musician friend wife learn n't alon mani peopl afraid ask help paralyz live relationship groundbreak book explor barrier life live around discov emot philosoph practic aspect art ask part manifesto part revel stori artist struggl new rule exchang twenti first centuri internet art ask inspir reader rethink idea ask give art love",
#  "updat reorgan fourth edit softwar test craftsman 's approach appli strong mathemat content previou edit coher treatment model base test code base structur specif base function test techniqu extend usual unit test discuss full coverag less understood level integr system test fourth edit emphas technic inspect supplement appendix full packag document requir sampl use case technic inspect introduc innov approach merg event driven petri net earlier edit swim lane concept unifi model languag uml permit model base test four level interact among constitu system system introduc model base develop provid explan conduct test within model base develop environ present new section method test softwar agil program environ explor test driven develop reexamin pair test explain four context softwar test thoroughli revis updat softwar test craftsman ’ approach fourth edit sure becom standard refer need stay date evolv technolog softwar test carri tradit previou edit continu serv valuabl refer softwar tester develop engin",
#  'transact process heart modern enterpris system book explain depth transact process technolog leverag java platform provid comprehens explan underli concept transact need understand exploit technolog correctli technic inform deliv book correspond directli latest revis java author cover transact aspect major j2ee compon work practic consequ implement choic addit text look beyond java standard implement provid broad interoper across heterogen applic environ final book provid look emerg web servic standard address next gener reliabl inform system',
#  'base author ’ first hand experi expertis book offer proven framework global softwar engin reader learn best practic manag varieti softwar project coordin activ sever locat across globe account cultur differ importantli reader learn engin first rate softwar product effici possibl fulli leverag global personnel resourc global softwar take uniqu approach work project size examin critic topic execut seamless project across multipl locationsmitig risk shoringdevelop implement process global developmentestablish practic outsourc guidelinesfost effect collabor commun across contin culturethi book provid balanc framework plan global develop cover topic manag peopl distribut site manag project across locat deliv comprehens busi model benefici anyon look cost effect effici way engin good softwar product',
#  "advanc prais carrot stick n't work paul marciano provid wealth prescript advic absolut make sens actual open book chapter gain idea immedi implement beverli kay coauthor love 'em lose 'em book hand anyon get work done peopl 's invalu tool manag level john l rice vice presid human resourc tyco intern carrot stick n't work provid commonsens approach employe engag dr marciano provid great real world insight data practic exampl truli bring respect model life rene selman presid catalina health resourc respect model one dynam engag thought provok employe engag tool seen dr marciano 's work help provid meaning long term benefit employe organ andi brantley presid ceo colleg univers profession associ human resourc book provid clear advic instruct engag team member inspir higher level product work satisfact enjoy alreadi util techniqu find immedi posit chang robert roth director account report colgat palmol compani titl say carrot stick n't work reward recognit program costli ineffici primarili reward employe alreadi highli engag product perform wors still program actual decreas employe motiv make individu recognit rather overal success team goal yet mani busi turn measur first—unawar better altern come chang organiz cultur carrot stick ’ work work dr paul marciano 's acclaim respect model give specif low cost turnkey solut action plan base seven key driver employe engag proven support decad research practice—that empow assess troubleshoot resolv engag issu workplac recognit acknowledg employe ' contribut empower via tool resourc inform set employe succeed support feedback ongo perform coach mentor partner encourag foster collabor work relationship expect set clear challeng attain perform goal consider let employe know care trust employe ' abil skill judgment carrot stick n't work deliv proven resourc techniqu enabl trainer execut manag owner oper rang branch unit state govern fortun 500 corpor twenti person outfit realiz demonstr gain employe product job satisfact give littl respect get effect organ reduc turnov absente employe level areengag focus commit succeed team short get maximum roi organ 's power resourc peopl",
#  'second edit book improv previou edit date current version 2 5 written around true patient encount also addit v2 5 xml encod exampl lab result hl7 health level 7 commun standard develop health care domain facilit exchang messag health care inform system radiolog laboratori patient schedul bill etc book provid comprehens guid hl7 version 2 x standard reader need experi hl7 standard book particular valu anyon work imag domain frequent refer made ihe integr health care enterpris standard defin profil especi imag domain book provid reader detail explan version 2 x messag make extens use exampl especi use plan implement support need good understand standard intend audienc engin system administr interfac engin personnel anyon want get thorough overview messag protocol',
#  "summari softwar develop metric handbook anyon need track guid softwar develop deliveri team level project manag team lead new develop practic includ agil methodolog like scrum redefin measur meaning condit benefit practic book identifi key characterist organiz structur process model develop method select appropri metric team describ use mechan common abus number metric use steer monitor process improv insight techniqu book base entir field experi purchas print book includ free ebook pdf kindl epub format man public book drive car less like speed run ga suffer engin failur measur car report condit develop team less like fail measur paramet matter success project book show softwar develop metric teach gather analyz effect use metric defin organiz structur process model develop method insight exampl book base entir field experi 'll learn practic techniqu like build tool track key metric develop data base earli warn system along way 'll learn metric align differ develop practic includ tradit adapt method formal experi develop appli metric assum 's insideidentifi valuabl metric team processdifferenti improv chang learn interpret appli data gathercommon pitfal anti patternsabout authordav nicolett organiz transform consult team coach trainer dave activ agil lean softwar commun tabl contentsmak metric usefulmetr steeringmetr improvementput metric workplan predictabilityreport outward upward",
#  "draw dale carnegi 's year experi busi trainer book show overcom natur fear public speak becom success speaker even learn enjoy invalu advic includ way develop pois gain self confid improv memori make mean clear begin end present effect interest charm audienc improv diction win argument without make enemi",
#  'book practic step step tutori plan deploy instal configur troubleshoot data protect manag 2010 take step requir use dpm effect back busi data network administr system administr backup administr storag administr consult want effect back busi data use microsoft data protect manag 2010 book good understand oper system backup devic network administr requir howev prior knowledg data protect manag necessari',
#  "opportun best everi day chanc n't often natur talent go untap cradl cubicl devot time fix shortcom develop strength help peopl uncov talent gallup introduc first version onlin assess strengthsfind 2001 ignit global convers help million discov top five talent latest nation bestsel strengthsfind 2 0 gallup unveil new improv version popular assess languag 34 theme much see detail read book one sit 'll use refer decad",
#  'practic guid popular agil process singl sourc comprehens guid scrum team member manag execut want use scrum develop innov product servic delight custom essenti scrum complet singl sourc refer ’ search lead scrum coach trainer kenni rubin illumin valu principl practic scrum describ flexibl proven approach help implement far effect whether new scrum year use book introduc clarifi deepen scrum knowledg team product portfolio level draw rubin ’ experi help hundr organ succeed scrum book provid easi digest descript enhanc two hundr illustr base entir new visual icon languag describ scrum ’ role artifact activ essenti scrum provid everi team member manag execut common understand scrum share vocabulari use appli practic knowledg deriv maximum valu',
#  "best defens increas threat social engin attack secur awar train warn organ 's staff risk educ protect organ 's data social engin new tactic build secur awar program first book show build success secur awar train program ground build secur awar program provid sound technic basi develop new train program book also tell best way garner manag support implement program author bill gardner one found member secur awar train framework walk process develop engag success train program organ help staff defend system network mobil devic data foreword written dave kennedi kevin mitnick practic guid set secur awar train program organ real world exampl show cyber crimin commit crime keep data safe learn propos new program manag benefit staff compani find variou type train best train cycl use metric success method build engag success program",
#  "practic book provid step step approach test mission critic applic scalabl perform 're deploy vital topic book devot one chapter busi today live die network applic web servic increas complex program pressur deploy quickli mani profession n't take time ensur 'll perform well scale effect art applic perform test explain complet life cycl test process demonstr best practic help plan gain approv coordin conduct perform test applic",
#  "peopl say build iphon app w html css javascript futur mobil develop clearli web technolog like css html javascript jonathan stark show leverag exist web develop skill build nativ iphon applic use technolog john allsopp author founder web direct jonathan 's book comprehens document avail develop web applic mobil safari great tech coverag book easi read pure fascin mobil tidbit fun colloqui style must phonegap develop brian leroux nitobi softwar 's fact know html css javascript alreadi tool need develop iphon app book 'll learn use open sourc web technolog design build app iphon ipod touch platform choic without use object c cocoa devic agnost mobil app wave futur book show creat one product sever platform 'll find guidelin convert product nativ iphon app use free phonegap framework 'll learn releas product web app first help find fix test bug much faster went straight app store product built appl 's tool build iphon app tool alreadi know use learn make exist websit look behav like iphon app add nativ look anim web app use jqtouch take advantag client side data storag app run even iphon offlin hook advanc iphon featur includ acceleromet geoloc vibrat javascript submit applic app store x",
#  "whether 's java net rubi rail get applic readi ship half battl design system survivef sudden rush visitor digg slashdot influx real world custom 100 differ countri readi world fill flakey network tangl databas impati user 're develop n't want call 3am rest life book help releas michael nygard show design architect applic harsh realiti face 'll learn design applic maximum uptim perform return invest mike explain mani problem system today start design",
#  'wide consid one best practic guid program steve mcconnel ’ origin code complet help develop write better softwar decad classic book fulli updat revis lead edg practices—and hundr new code samples—illustr art scienc softwar construct captur bodi knowledg avail research academia everyday commerci practic mcconnel synthes effect techniqu must know principl clear pragmat guidanc matter experi level develop environ project size book inform stimul thinking—and help build highest qualiti code discov timeless techniqu strategi help design minimum complex maximum creativ reap benefit collabor develop appli defens program techniqu reduc flush error exploit opportun refactor—or evolve—cod safe use construct practic right weight project debug problem quickli effect resolv critic construct issu earli correctli build qualiti begin middl end project',
#  "want better develop book collect person habit idea approach success agil softwar develop present seri short easi digest tip n't academ fluff follow idea 'll show teammat manag real result proven effect agil practic make better develop book help improv five area career develop process code develop attitud project team manag iter increment learningthes practic provid guidelin help succeed deliv meet user 's expect even domain unfamiliar 'll abl keep normal project pressur turn disastr stress write code see effect coordin mentor team lead develop harmoni learn stuff hard way book save time pain read 'll better develop",
#  'live world broken believ must effici way peopl get thing done scrum pioneer jeff sutherland brilliantli discurs thought provok book manag process chang way live futur historian may look back human progress draw sharp line design “ scrum ” “ scrum ” scrum ground break alreadi drive world ’ top technolog compani ’ start spread everi domain peopl wrestl complex project ’ ever startl fast world chang scrum one reason product gain much 1200 record ’ lucid – compel – explain scrum bright promis jeff sutherland man put togeth first scrum team twenti year ago thorni problem jeff began tackl back boil peopl spectacularli bad thing quickli effici best laid plan go smoke team often work cross purpos pressur rise unhappi soar draw experi west point educ fighter pilot biometr expert earli innov atm technolog v p engin cto eleven differ technolog compani jeff began challeng dysfunct realiti look solut would global impact book ’ journey scrum ’ front line jeff ’ system deep account team interact constant iter improv among feat bring fbi 21st centuri perfect design afford 140 mile per hour 100 mile per gallon car help npr report fast move action middl east chang way pharmacist interact patient reduc poverti third world even help peopl plan wed accomplish weekend chore woven insight martial art judici decis make advanc aerial combat robot mani disciplin scrum consist rivet import reason read book may help achiev other consid unachiev – whether invent trailblaz technolog devis new system educ pioneer way feed hungri closer home build foundat famili thrive prosper',
# ...
#  "1 tac fake analyst cao hoang nguyen minh economi pham van minh tran thi minh ngoc nguyen phuoc nguyen phuong hoang thi thu thanh huynh thien vu quoc vietnam websit http www phantichkinhte123 com fp http www facebook com trangphantichkinht 2 work use product one year gafam giant googl amazon facebook appl microsoft make doubt contribut data larg data big data global world today daili activ consum commun move creat data trace numer debri fact scientif data data scienc establish handl record time divers data less structur grow constantli chang applic almost area affect aspect life occas step oper tuesday econom analysi page 20 articl select introduc topic hot set second volum 1 group consist three main section nine head collect present understand big data via number illustr applic variou disciplin econom educ journal histori urban manag medicin etc nine subsequ mention sever issu debat inform technolog new handl greater data chang philosophi computer transform econom social technolog make pose problem privaci individu whether complet break scientif reason transit method assumpt infer base modern scienc built induct logic differ tradit last two articl help read easi imagin peopl scientif data delin practic skill need work everi day big data hope collect multi dimension perspect help reader identifi prospect challeng new techniqu also track thrive almost sober face activ way 1 select learn teach first dismal scienc post crisi publish nation univers ho chi minh citi 2015 3 content introduct 7 illustr big data big data serv poorest 11 big data poor student 19 data mine show level ghost town china 25 profil panama technic challeng media data 31 econom forecast era larg data 45 one economist adapt event 51 big data affect econom historian like 57 promis big data 65 risk conceal larg data 77 round thread debat joint statement theori field extract data make scientif method obsolet 77 social data societi statist 91 big data z 95 data larg wrong 111 big data prophet badli brian cox interview tim harford 135 big data creat three breakag 145 big data person data toward manag ethic big data 163 algorithm energi bewar big disappoint 145 big data support energi transit 187 data scienc practic becom data scientist 's job 195 data scientist 211 index 229",
#  'book stori author built unit diamond andin intern use principl collect intellectu ancient buddhism noth function student world mani million dollar year decis polici author unit author vice chairman failur play rule find book principl divid ba nguyen first rule busi succeed ie must gener cash popular belief us west success make money way mistak anyon tri spiritu life buddhism though money bad fact person money good deed world main problem make money somehow understand money aris money continu come maintain healthi attitud money switch khong nguyen second enjoy money ie need learn keep spirit bodi healthi make money oper asset gener make us tire physic mental enjoy properti devast health busi busi dissip ie real purpos doanh nguyen third principl look back get busi career final honestli year busi sens tom busi purpos ancient tibetan wisdom inde human endeavor make rich achiev prosper outsid insid enjoy prosper maintain high level physic health mental throughout life must find way make prosper meaning broader perspect',
#  'need work harder even may need compli order step step guidanc bestsel get thing done difficulti howev time must better control part work complet innov abl cover better focu thing care creativ new structur job flexibl comfort simpli prepar advanc next step keen desir build better life job attract book make definit',
#  "allen 's messag briefli pleas reorgan liber mind focu truli deserv achiev highest product without stress book everyth done difficult coach veteran manag consult david allen share effect method help well ten thousand other train stress reduct find comfort live everyth done difficult know appli principl make transfer suspens skip free memori reassess goal maintain abil refocu circumst chang plan seek remov project hang overcom feel confus anxiou unabl control feel satisfi realli",
#  "continu explor organ complex scienc design new edit herbert simon 's classic work artifici intellig add chapter sort current theme tool chao adapt system genet algorithm analyz complex complex system updat throughout book well take account import advanc cognit psycholog scienc design confirm extend book 's basic thesi physic symbol system necessari suffici mean intellig action chapter econom realiti also revis reflect chang emphasi simon 's think respect role organ market econom system",
#  'book fast pace guid help clear exam confid learn design develop deploy cloud base solut use aw enhanc aw skill practic question mock test book book profession develop look clear aw certifi develop associ 2017 exam develop look develop manag applic aw platform also find book use prior aw experi need learn creat manag user group permiss use aw ident access manag servic creat secur virtual privat cloud vpc public privat subnet network access control secur group get start elast comput cloud ec2 launch first ec2 instanc work handl applic traffic elast load balanc elb monitor aw resourc cloudwatch work aw storag servic simpl storag servic s3 glacier cloudfront get acquaint aw dynamodb nosql databas servic coordin work across distribut applic compon use simpl workflow servic swf detail aw certifi develop associ guid start quick introduct aw prerequisit get start book give fair understand core aw servic basic architectur next book describ get familiar ident access manag iam along virtual privat cloud vpc move ahead learn elast comput cloud ec2 handl applic traffic elast load balanc elb go ahead talk monitor cloudwatch simpl storag servic s3 glacier cloudfront along aw storag option next take aw dynamodb nosql databas servic amazon simpl queue servic sq cloudform overview final book cover understand elast beanstalk overview aw lambda end book cover enough topic tip trick along mock test abl pass aw certifi develop associ exam develop well manag applic aw platform style approach step step guid includ exercis mock test clear aw certif exam becom success aw develop tabl content overview aw certifi develop associ certif introduct cloud comput aw get familiar ident access manag virtual privat cloud get start elast comput cloud handl applic traffic elast load balanc monitor cloudwatch simpl storag servic glacier cloudfront aw storag option aw relat databas servic aw dynamodb nosql databas servic amazon simpl queue servic simpl notif servic simpl workflow servic aw cloudform elast beanstalk overview aw lambda mock test',
#  'thorough coverag improv chang sharepoint 2010 sharepoint 2010 boast varieti incred new featur challeng even experienc administr upgrad sharepoint 2007 written team sharepoint expert book place take aim show make new featur work right offer depth look sharepoint 2010 author focu sharepoint function chang earliest version newest provid detail coverag new featur capabl present depth coverag new featur function sharepoint 2010 demonstr instal configur upgrad exist sharepoint 2007 server discuss architectur capac plan secur manag site content integr offic client detail protocol handl monitor creat backup execut disast recoveri address share servic applic navig govern busi intellig report servic profession sharepoint 2010 present solid understand function sharepoint 2010 provid allow see',
#  "get jump start build applic bootstrap today origin develop twitter bootstrap framework make arduou process craft fulli respons web design breez discov bootstrap fast becom favorit tool top web design one weekend hand tutori 'll learn integr bootstrap projectsunderstand basic bootstrap templatework bootstrap 's gridcustom bootstrap work project",
#  'past 10 year distribut system becom fine grain larg multi million line long monolith applic see benefit smaller self contain servic rather heavi weight hard chang servic orient architectur see system consist collabor microservic easier chang deploy requir retir organ right posit take advantag yield signific benefit book take holist view thing need cogniz order pull cover enough understand technolog architectur oper organ show move toward finer grain system',
#  'choos sever data access framework build java enterpris applic work relat databas big data hand introduct show spring data make rel easi build applic across wide rang new data access technolog nosql hadoop sever sampl project ’ learn spring data provid consist program model retain nosql specif featur capabl help develop hadoop applic across wide rang use case data analysi event stream process workflow ’ also discov featur spring data add spring ’ exist jpa jdbc support write rdbm base data access layer learn spring ’ templat helper class simplifi use databas specif function explor spring data ’ repositori abstract advanc queri function use spring data redi key valu store hbase column famili mongodb document databas neo4j graph databas discov gemfir distribut data grid solut export spring data jpa manag entiti web rest web servic simplifi develop hbase applic use lightweight object map framework build exampl big data pipelin spring batch spring integr',
#  'david meerman scott market bibl becom modern day busi classic book everi ambiti forward think progress market publicist front shelf busi commun chang recent year creativ ad copi longer enough new rule market pr brought thousand market speed chang requir promot product servic new digit age one kind pioneer guid offer step step action plan har power internet commun buyer directli rais onlin visibl increas sale get right messag right peopl right time fraction cost big budget advertis campaign new updat edit includ new introduct discuss recent chang world market pra brand new chapter mobil marketingan addit chapter real time market prupdat inform measur success campaignsa rang new toolsfresh case studi',
#  "microsoft 's window present foundat wpf provid foundat build applic high qualiti user experi window oper system blend applic user interfac document media content exploit full power comput 's oper system function extend support tablet pc form input devic provid modern imag print pipelin access ui autom infrastructur data driven user interfac visual integr point weav applic experi window shell book show wpf realli work provid nonsens practic advic need order build high qualiti wpf applic quickli easili give firm foundat goe explor advanc aspect wpf relat other element net 4 0 platform associ technolog silverlight",
#  "someon use jqueri regular basi surpris discov much librari ’ use book indispens anyon seriou use jqueri non trivial applic raffael cecco longtim develop video game includ cybernoid exolon stormlordjqueri write less javascript librari power featur eas use made popular client side javascript framework web ideal javascript develop skill level book jqueri 's trusti companion definit read less learn guid librari jqueri pocket refer explain everyth need know jqueri complet comprehens 'll learn select manipul document elementsalt document structurehandl trigger eventscr visual effect animationsscript http ajax utilitiesus jqueri 's selector select method util plugin moreth 25 page quick refer summar librari list jqueri method function signatur descript",
#  'would like use consist visual notat draw integr solut look insid front cover want har power asynchron system without get caught pitfal see think asynchron introduct want know style applic integr best purpos see chapter 2 integr style want learn techniqu process messag concurr see chapter 10 compet consum messag dispatch want learn track asynchron messag flow across distribut system see chapter 11 messag histori messag store want understand system design use integr pattern implement use java web servic net messag queu tibco base publish subscrib architectur see chapter 9 interlud compos messag util year practic experi season expert gregor hohp bobbi woolf show asynchron messag proven best strategi enterpris integr success howev build deploy messag solut present number problem develop enterpris integr pattern provid invalu catalog sixti five pattern real world solut demonstr formid messag help design effect messag solut enterpris author also includ exampl cover varieti differ integr technolog jm msmq tibco activeenterpris microsoft biztalk soap xsl case studi describ bond trade system illustr pattern practic book offer look emerg standard well insight futur enterpris integr might hold book provid consist vocabulari visual notat framework describ larg scale integr solut across mani technolog also explor detail advantag limit asynchron messag architectur author present practic advic design code connect applic messag system provid extens inform help determin send messag rout proper destin monitor health messag system want know manag monitor maintain messag system use get book 0321200683b09122003',
#  "want sound like nativ speaker english need key phrase convers tool nativ speaker use get messag across collin speak help becom confid fluent speaker english choos right word pronunci tone learn start convers keep convers go deal difficult situat includ practic start convers interrupt make suggest give receiv compliment ask give opinion say polit collin speak part new english life seri use authent materi collin corpu world 's largest databas english languag suitabl self studi classroom use help toward cambridg fce prepar suitabl intermedi learner english cef level b1+",
#  'compil net common languag runtim give softwar engin critic inform creat net compil implement net program languag renown compil expert john gough goe ¿under hood¿ clr illumin key concept cover everi facet architectur behavior gough present extens exampl mani drawn c gough¿ open sourc garden point compon pascal compil',
#  '180 grammar topic organ 2 page section explain grammar topic use avoid mistak includ tip help student sound natur cover topic student need know cambridg esol exam fce cae cpe',
#  "visionari ceo zappo explain emphasi corpor cultur lead unpreced success pay new employe 2000 quit make custom servic entir compani depart focu compani cultur 1 prioriti appli research scienc happi run busi help employe grow person profession seek chang world oh make money sound crazi 's standard oper procedur zappo com onlin retail 's 1 billion gross merchandis sale everi year 1999 toni hsieh pronounc shay sold linkexchang compani co found microsoft 265 million join zappo advis investor eventu becam ceo 2009 zappo list one fortun magazin 's top 25 compani work acquir amazon later year deal valu 1 2 billion day close first book toni share differ busi lesson learn life lemonad stand pizza busi linkexchang zappo ultim show use happi framework produc profit passion purpos busi life edit author",
#  "build high perform team evid base framework deliv result commit team three step inspir passion perform base decept simpl philosophi set direct tri stay track make adjust necessari easi hardli especi typic workday time crunch stress deadlin driven draw research done wharton school busi author reveal deliv result tough condit test refin wharton 's execut develop program commit team help gain buy share object assign role right peopl establish norm effect collabor whether team aim execut strategi produc breakthrough innov collabor across global boundari launch new ventur guid offer pragmat advic need engag stori illustr exampl busi entertain sport art bring three step process life game chang book provid tool align everi member team behind motiv visionmak team meet effici productiveclos gap state goal actual behavior want competit demand fast pace work environ need reli high perform team commit team indispens resourc creat one"]

# %% [markdown]
# ## TFIDF
# https://en.wikipedia.org/wiki/Tf%E2%80%93idf
#
# **TFIDF**, short for "*term frequency–inverse document frequency*", is a numerical statistic that is intended to reflect how important a word is to a document in a collection or corpus.[1] It is often used as a weighting factor in searches of information retrieval, text mining, and user modeling. TFIDF is one of the most popular term-weighting schemes today; 83% of text-based recommender systems in digital libraries use TFIDF.
#
# **TFIDF** equation include 2 parts, **TF** and **IDF**
#
# ### TF ( Term Frequency )
# TF = how often a word appear in a doccument
#
# $TF(i,j)=\frac{\text{Word i frequency in document j}}{\text{Number of words in document j}}$
#
# ### IDF (Inversed Document Frequency)
# IDF = how many documents contain a particular word. This make sure common words doesn't take too much weight when compare documents
#
# $IDF(i) = \log{(\frac{Number of documents}{Number of documents the word i appear in})}$
#
# ### Final Equation
# $TFIDF = TF\cdot{IDF}$
#
# ![title](assets/tfidf-sample.png)

# %%
tfidf = TfidfVectorizer()
doc_vectors = tfidf.fit_transform(corpus)

# %%
print("Shape of our document matrix",doc_vectors.shape)
# Out:
# Shape of our document matrix (440, 5589)

# %% [markdown]
# ## Build RS systems
#
# In content-based RS, we recommend based on the **similarity** between **new items** with the **items users has interacted with**.
#
# ### How to measure similarity
#
# There are many metrics we can use when to try to measure the similarity between 2 vectors:
#
# - cosine similarity
# - pearson similarity
# - euclidean distance
# - etc
#
# ### Euclidean Distance
#
# ![title](./assets/Euclidean_distance.png)
#
# To measure the distance between point $(x1,y1)$ and $(x2,y2)$ we can use the Pythagorean Theorem:
#
# $$d = \sqrt{(x_1-x_2)^2 + (y_1-y_2)^2}$$
#
# However, the Pythagorean Theorem doesn't limit us to 2-dimensional space. Infact, this theorem work at any N dimensions. The general equation to calculate the distance between 2 point __*P*__ and __*Q*__ in N-dimension:
#
# $$d = \sqrt{(P_1-Q_1)^2+(P_2-Q_2)^2 + ... + (P_n-Q_n)^2}$$
# $$\text{Where:}$$
# $$P = <P_1,P_2,...,P_n>$$
# $$Q = <Q_1,Q_2,...,Q_n>$$

# %%
def similar_books(bookIndex,k=10,timeit=False):
    target = doc_vectors[bookIndex]    
    dist = [euclidean_distances(target,i)[0][0] for i in doc_vectors]
    dist = np.argsort(dist)
    recommended = data.iloc[dist][1:k+1]['Title']
    if not timeit:
        print(f"Similar books to '{data.iloc[bookIndex]['Title']}'\n")
        for b in recommended:
            print(b)

# %%
similar_books(231)
# Out:
# Similar books to 'CBAP / CCBA Exam Prep, Premier Edition: A Course in a Book for Becoming an IIBA Certified Business Analyst'
#
# Business Analysis: Best Practices for Success
# AWS Certified Solutions Architect - Professional: The Definitive Study Guide
# Cẩm Nang Kinh Doanh - Tài Chính Dành Cho Người Quản Lý
# Head First Pmp: A Brain-Friendly Guide to Passing the Project Management Professional Exam
# Oxford Business English Dictionary for learners of English Dictionary and CD-ROM Pack
# A Guide to the Business Analysis Body of Knowledge (BABOK Guide)
# HL7 Study Guide
# Market Leader Intermediate Coursebook and DVD-Rom Pack 3rd Edition
# PMP Exam Prep, Seventh Edition
# Cẩm Nang Kinh Doanh - Huấn Luyện Và Truyền Kinh Nghiệm

# %%
doc_vectors
# Out:
# <440x5589 sparse matrix of type '<class 'numpy.float64'>'
# 	with 35159 stored elements in Compressed Sparse Row format>

# %%
row=440
col=5589
size=8 #bytes
print(f"Total memory ~{np.prod([row,col,size])/1e6} mb")
# Out:
# Total memory ~19.67328 mb

# %%
# %timeit similar_books(21,10,True)
# Out:
# 166 ms ± 12.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ### Pre-compute the similarity matrix

# %%
books_similarity = euclidean_distances(doc_vectors)

# %%
books_similarity.shape
# Out:
# (440, 440)

# %%
row=440
col=440
size=8 #bytes
print(f"Total memory ~ {np.prod([row,col,size])/1e6} mb")
# Out:
# Total memory ~ 1.5488 mb

# %%
def similar_books_v2(bookIndex,k=10,timeit=False):
    dist = np.argsort(books_similarity[bookIndex])
    recommended = data.iloc[dist][1:k+1]['Title']
    if not timeit:
        print(f"Similar books to '{data.iloc[bookIndex]['Title']}'\n")
        for b in recommended:
            print(b)

# %%
similar_books_v2(21)
# Out:
# Similar books to 'Interviewer Success: Become a Great Interviewer in Less Than One Hour'
#
# Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng Phỏng Vấn
# "Headhunter" Hiring Secrets: The Rules of the Hiring Game Have Changed . . . Forever!
# Hiring the Best: Manager's Guide to Effective Interviewing and Recruiting, Fifth Edition
# Growing Great Employees: Turning Ordinary People into Extraordinary Performers
# Strengths-Based Leadership
# Cẩm Nang Quản Lý Hiệu Quả - Thông Tin Hiệu Quả
# Bí Quyết Tuyển Dụng Và Đãi Ngộ Người Tài
# The Business Analyst's Handbook
# Fun Works: Creating Places Where People Love to Work
# Cẩm Nang Quản Lý Hiệu Quả - Kinh Doanh Hiệu Quả

# %%
# %timeit similar_books_v2(21,10,True)
# Out:
# 498 µs ± 3.46 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
160 / (599 / 1000)
# Out:
# 267.1118530884808

# %% [markdown]
# ### Recommend new books to users
#
# ![title](./assets/becauseyouwatch.png)

# %%
transaction = pd.read_csv("./data/transactions.csv")

# %%
transaction
# Out:
#                                                   Title     Action  \
# 0     Request: Accelerate: The Science of Lean Softw...  Check out
# 1     Request: Continuous Delivery: Reliable Softwar...  Check out
# 2     Request: AWS Certified Developer - Associate G...  Check out
# 3     Request: Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng T...  Check out
# 4     Request: Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng T...  Check out
# ...                                                 ...        ...
# 3431                Request: Tôi Tài Giỏi Bạn Cũng Thế!       View
# 3432  Request: Sample Exam Questions: ISTQB Certifie...       View
# 3433  Request: Human Resource Management, Fourth Edi...       View
# 3434  Request: Human Resource Management, Fourth Edi...       View
# 3435  Request: Human Resource Management, Fourth Edi...       View
#
#               Check Out To Request Status Borrow From  Borrow To  \
# 0     Giang Thi Tra Nguyen      Requested    4/2/2019   5/2/2019
# 1              Uyen Nguyen      Requested    4/1/2019   5/1/2019
# 2               Nhan Quach      Requested    4/1/2019   5/1/2019
# 3              Thong Huynh      Requested   3/29/2019  4/23/2019
# 4              Thong Huynh      Requested   3/29/2019  4/23/2019
# ...                    ...            ...         ...        ...
# 3431         Ha Thu Nguyen     Checked In   5/27/2010   6/9/2010
# 3432             Lan Duong     Checked In   5/24/2010   6/8/2010
# 3433             Xuan Tran     Checked In   4/16/2010  4/27/2010
# 3434              Triet Ho       Rejected   3/31/2010   4/1/2010
# 3435             Quang Luu     Checked In   5/11/2010  5/26/2010
#
#       Transaction Created  Handle Books Copies and Action  \
# 0                     2.0                             5.0
# 1                     2.0                             5.0
# 2                     2.0                             5.0
# 3                     2.0                             5.0
# 4                     2.0                             5.0
# ...                   ...                             ...
# 3431                  NaN                             NaN
# 3432                  NaN                             NaN
# 3433                  NaN                             NaN
# 3434                  NaN                             NaN
# 3435                  NaN                             NaN
#
#                 Created By Item Type                        Path
# 0     Giang Thi Tra Nguyen      Item  library/Lists/Transactions
# 1              Uyen Nguyen      Item  library/Lists/Transactions
# 2               Nhan Quach      Item  library/Lists/Transactions
# 3              Thong Huynh      Item  library/Lists/Transactions
# 4              Thong Huynh      Item  library/Lists/Transactions
# ...                    ...       ...                         ...
# 3431         Ha Thu Nguyen      Item  library/Lists/Transactions
# 3432             Lan Duong      Item  library/Lists/Transactions
# 3433             Xuan Tran      Item  library/Lists/Transactions
# 3434              Triet Ho      Item  library/Lists/Transactions
# 3435             Quang Luu      Item  library/Lists/Transactions
#
# [3436 rows x 11 columns]

# %%
transaction = transaction[['Title','Check Out To']].rename(columns={'Title':'title','Check Out To':'user'})

# %%
transaction
# Out:
#                                                   title                  user
# 0     Request: Accelerate: The Science of Lean Softw...  Giang Thi Tra Nguyen
# 1     Request: Continuous Delivery: Reliable Softwar...           Uyen Nguyen
# 2     Request: AWS Certified Developer - Associate G...            Nhan Quach
# 3     Request: Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng T...           Thong Huynh
# 4     Request: Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng T...           Thong Huynh
# ...                                                 ...                   ...
# 3431                Request: Tôi Tài Giỏi Bạn Cũng Thế!         Ha Thu Nguyen
# 3432  Request: Sample Exam Questions: ISTQB Certifie...             Lan Duong
# 3433  Request: Human Resource Management, Fourth Edi...             Xuan Tran
# 3434  Request: Human Resource Management, Fourth Edi...              Triet Ho
# 3435  Request: Human Resource Management, Fourth Edi...             Quang Luu
#
# [3436 rows x 2 columns]

# %%
for i,x in transaction.iterrows():
    title = x['title']
    transaction.at[i,'title'] = title[9:]

# %%
transaction
# Out:
#                                                   title                  user
# 0     Accelerate: The Science of Lean Software and D...  Giang Thi Tra Nguyen
# 1     Continuous Delivery: Reliable Software Release...           Uyen Nguyen
# 2     AWS Certified Developer - Associate Guide: You...            Nhan Quach
# 3      Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng Thương Lượng           Thong Huynh
# 4      Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng Thuyết Trình           Thong Huynh
# ...                                                 ...                   ...
# 3431                         Tôi Tài Giỏi Bạn Cũng Thế!         Ha Thu Nguyen
# 3432  Sample Exam Questions: ISTQB Certified Tester ...             Lan Duong
# 3433  Human Resource Management, Fourth Edition: The...             Xuan Tran
# 3434  Human Resource Management, Fourth Edition: The...              Triet Ho
# 3435  Human Resource Management, Fourth Edition: The...             Quang Luu
#
# [3436 rows x 2 columns]

# %%
def book_read_by_user(user):
    books = transaction[transaction['user']==user]['title']
    books = data[data['Title'].isin(books)]['Title'].values
    for b in books:
        print('-',b)

# %%
book_read_by_user('Dung Vo')
# Out:
# - The Web Application Hacker's Handbook: Finding and Exploiting Security Flaws
# - Behind the Cloud: The Untold Story of How Salesforce.com Went from Idea to Billion-Dollar Company-and Revolutionized an Industry
# - Accelerate: The Science of Lean Software and DevOps: Building and Scaling High Performing Technology Organizations
# - Domain-Driven Design: Tackling Complexity in the Heart of Software
# - Don't Make Me Think, Revisited: A Common Sense Approach to Web Usability (3rd Edition)
# - Working Effectively with Legacy Code

# %%
def recommend_to_user(user,k=5):
    books = transaction[transaction['user']==user]['title']
    books_idx = data[data['Title'].isin(books)].index.values
    for idx in books_idx:
        dist = np.argsort(books_similarity[idx])
        recommened = data.iloc[dist][:k+1]['Title'].values
        print("Because you read:",recommened[0])
        print()
        for b in recommened[1:]:
            print("\t",b)
        print("--------------------------------")

# %%
recommend_to_user("Thong Huynh")
# Out:
# Because you read: Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng Thuyết Trình
#
# 	 Cẩm Nang Quản Lý Hiệu Quả - Hành Động Hiệu Quả
# 	 Cẩm Nang Quản Lý Hiệu Quả - Thông Tin Hiệu Quả
# 	 Cẩm Nang Quản Lý Hiệu Quả - Phân Công Hiệu Quả
# 	 Cẩm Nang Quản Lý Hiệu Quả - Đánh Giá Năng Lực Nhân Viên
# 	 Power Through Presentations: Tips and Tricks to Build a Better Slide Deck
# --------------------------------
# Because you read: Cẩm Nang Quản Lý Hiệu Quả - Kỹ Năng Thương Lượng
#
# 	 Cẩm Nang Kinh Doanh - Kỹ Năng Thương Lượng
# 	 Getting To Yes: Negotiating Agreement Without Giving In
# 	 Cẩm Nang Quản Lý Hiệu Quả - Đánh Giá Năng Lực Nhân Viên
# 	 Cẩm Nang Quản Lý Hiệu Quả - Thông Tin Hiệu Quả
# 	 Cẩm Nang Quản Lý Hiệu Quả - Quản Lý Toàn Cầu
# --------------------------------
# Because you read: Big Data - Tuyển tập dữ liệu lớn
#
# 	 Big Data For Dummies
# 	 Big Data: Principles and best practices of scalable realtime data systems
# 	 Hadoop in Practice
# 	 Agile Data Science 2.0: Building Full-Stack Data Analytics Applications with Spark
# 	 Storytelling with Data: A Data Visualization Guide for Business Professionals
# --------------------------------
